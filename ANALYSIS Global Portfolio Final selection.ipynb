# %%
import US_indices.composite_portfolio_analysis_Buy_and_Hold as cpa
from importlib import reload
reload(cpa)

from US_indices.composite_portfolio_analysis_Buy_and_Hold import compare_portfolios

# %% [markdown]
# # EM index

# %%
# Define two portfolio options
portfolios_to_compare = [
    {
        'name': 'RAFIFunHighLiq-EM',
        'weights': [
            ('RAFI Fundamental High Liquidity Emerging Markets Large Index', 1),
        ]
    },
    # {
    #     'name': 'FunSel-EM-350',
    #     'weights': [
    #         ('RAFI Fundamental Select Emerging Markets 350 Index', 1),
    #     ]
    # },

]
# Run the comparison
summary = compare_portfolios(
    portfolios_to_compare,
    risk_free_rate=3.5,
    sip_amount=10000,
    show_plots=False,
    export_csv=False,
    search_path='.',          # where your CSV files are
    recursive=True,
    output_fname="example",
    # start_date=None,        # new
    # end_date=None
    # start_date='2011-01-01',
    # end_date='2010-12-31',        # new
    data_format='auto',
    plot_running_cagr=True,
    running_cagr_periods=[3,4,5,7,10],
    # running_cagr_periods=[2,3,4,5],
    plot_running_xirr=False,
    plot_rolling_returns_percentiles=True,
    rolling_percentiles_to_show=[0,5, 10, 25, 50, 75, 85, 90, 95,100],
    display_rolling_returns_table=False,
    interactive_cagr=True
)
# Out:
# ====================================================================================================
#  COMPARING 1 PORTFOLIOS
# ====================================================================================================
#  Unique indices needed: 1
#    - RAFI Fundamental High Liquidity Emerging Markets Large Index
#
# 📂 Loading index data...
#
# ✅ Global common date grid: 1996-04-02 to 2026-03-20 (7753 days)
#
# [1/1] Processing: RAFIFunHighLiq-EM
# ------------------------------------------------------------
# ✅ Successfully processed: RAFIFunHighLiq-EM
#
# 📊 COMBINED SUMMARY - ALL PORTFOLIOS (COMMON DATES)
# ====================================================================================================
#                                  Date Range Total Trading Days Start Value End Value Total Return % CAGR % Annualized Volatility % Sharpe Ratio Max Drawdown % Max Drawdown Date SIP XIRR % SIP Return % SIP Invested Amt SIP Final Amt Positive Days % Negative Days % Max Daily Return % Min Daily Return % 3Y Rolling Avg % 3Y Rolling Median % 3Y Rolling Min % 3Y Rolling Max % 5Y Rolling Avg % 5Y Rolling Median % 5Y Rolling Min % 5Y Rolling Max % 7Y Rolling Avg % 7Y Rolling Median % 7Y Rolling Min % 7Y Rolling Max % 10Y Rolling Avg % 10Y Rolling Median % 10Y Rolling Min % 10Y Rolling Max % 2026 Return % 2025 Return % 2024 Return % 2023 Return % 2022 Return %
# RAFIFunHighLiq-EM  1996-04-03 to 2026-03-20               7752         1.0     26.19        2529.72  11.53                   19.06        0.421         -63.27        2008-10-27     12.35%       810.41          3600000   32774641.64           54.66           44.93              13.81              -10.0            12.52                9.24           -14.02            61.62             12.1                8.99            -8.94            48.21            12.26                9.17            -1.31            34.45             12.11                10.71              0.84             31.27       3.38357     30.185547     14.701448      18.86621    -12.236271
#
# 📈 Generating comparison plots...
# 📊 Precomputing rolling returns for all periods...
#    Computing 3Y rolling returns...
#    Computing 4Y rolling returns...
#    Computing 5Y rolling returns...
#    Computing 7Y rolling returns...
#    Computing 10Y rolling returns...
# ✅ Precomputation complete!
#
# ================================================================================
#  INTERACTIVE RUNNING CAGR PLOT
# ================================================================================
# Rolling periods available: [3, 4, 5, 7, 10]
# Use the slider below to select the rolling period
# --------------------------------------------------------------------------------
# interactive(children=(SelectionSlider(description='Rolling Period (years):', layout=Layout(width='500px'), opt…

# %% [markdown]
# # Dev ex US index

# %%
# Define two portfolio options
portfolios_to_compare = [

    {
        'name': 'MultiFac Dev-ex-US',
        'weights': [
            ('RAFI Dynamic Multi-Factor Developed ex US Index', 1),
        ]
    },
    # {
    #     'name': 'FunSel-EM-350',
    #     'weights': [
    #         ('RAFI Fundamental Select Emerging Markets 350 Index', 1),
    #     ]
    # },

]
# Run the comparison
summary = compare_portfolios(
    portfolios_to_compare,
    risk_free_rate=3.5,
    sip_amount=10000,
    show_plots=False,
    export_csv=False,
    search_path='.',          # where your CSV files are
    recursive=True,
    output_fname="example",
    # start_date=None,        # new
    # end_date=None
    # start_date='2011-01-01',
    # end_date='2010-12-31',        # new
    data_format='auto',
    plot_running_cagr=True,
    running_cagr_periods=[3,4,5,7,10],
    # running_cagr_periods=[2,3,4,5],
    plot_running_xirr=False,
    plot_rolling_returns_percentiles=True,
    rolling_percentiles_to_show=[0,5, 10, 25, 50, 75, 85, 90, 95,100],
    display_rolling_returns_table=False,
    interactive_cagr=True
)
# Out:
# ====================================================================================================
#  COMPARING 1 PORTFOLIOS
# ====================================================================================================
#  Unique indices needed: 1
#    - RAFI Dynamic Multi-Factor Developed ex US Index
#
# 📂 Loading index data...
#
# ✅ Global common date grid: 1992-05-04 to 2026-03-20 (8788 days)
#
# [1/1] Processing: MultiFac Dev-ex-US
# ------------------------------------------------------------
# ✅ Successfully processed: MultiFac Dev-ex-US
#
# 📊 COMBINED SUMMARY - ALL PORTFOLIOS (COMMON DATES)
# ====================================================================================================
#                                   Date Range Total Trading Days Start Value End Value Total Return % CAGR % Annualized Volatility % Sharpe Ratio Max Drawdown % Max Drawdown Date SIP XIRR % SIP Return % SIP Invested Amt SIP Final Amt Positive Days % Negative Days % Max Daily Return % Min Daily Return % 3Y Rolling Avg % 3Y Rolling Median % 3Y Rolling Min % 3Y Rolling Max % 5Y Rolling Avg % 5Y Rolling Median % 5Y Rolling Min % 5Y Rolling Max % 7Y Rolling Avg % 7Y Rolling Median % 7Y Rolling Min % 7Y Rolling Max % 10Y Rolling Avg % 10Y Rolling Median % 10Y Rolling Min % 10Y Rolling Max % 2026 Return % 2025 Return % 2024 Return % 2023 Return % 2022 Return %
# MultiFac Dev-ex-US  1992-05-05 to 2026-03-20               8787         1.0     22.69         2171.9   9.66                   14.33         0.43         -54.93        2009-03-09      9.68%       599.36          4070000   28464026.84           53.06           44.74               7.02             -10.25             9.03                8.84            -14.3            35.17             8.75                8.15            -4.47            28.29             8.52                7.86             0.96            17.42              8.54                 8.48               3.3             14.62      1.062783      35.27588      5.266384     17.062975     -9.676542
#
# 📈 Generating comparison plots...
# 📊 Precomputing rolling returns for all periods...
#    Computing 3Y rolling returns...
#    Computing 4Y rolling returns...
#    Computing 5Y rolling returns...
#    Computing 7Y rolling returns...
#    Computing 10Y rolling returns...
# ✅ Precomputation complete!
#
# ================================================================================
#  INTERACTIVE RUNNING CAGR PLOT
# ================================================================================
# Rolling periods available: [3, 4, 5, 7, 10]
# Use the slider below to select the rolling period
# --------------------------------------------------------------------------------
# interactive(children=(SelectionSlider(description='Rolling Period (years):', layout=Layout(width='500px'), opt…

# %%
# Define two portfolio options
portfolios_to_compare = [

    {
        'name': 'FunHighLiq-Dev-ex-US-L',
        'weights': [
            ('RAFI Fundamental High Liquidity Developed ex US Large Index', 1),
        ]
    },
    # {
    #     'name': 'FunSel-EM-350',
    #     'weights': [
    #         ('RAFI Fundamental Select Emerging Markets 350 Index', 1),
    #     ]
    # },

]
# Run the comparison
summary = compare_portfolios(
    portfolios_to_compare,
    risk_free_rate=3.5,
    sip_amount=10000,
    show_plots=False,
    export_csv=False,
    search_path='.',          # where your CSV files are
    recursive=True,
    output_fname="example",
    # start_date=None,        # new
    # end_date=None
    # start_date='2011-01-01',
    # end_date='2010-12-31',        # new
    data_format='auto',
    plot_running_cagr=True,
    running_cagr_periods=[3,4,5,7,10],
    # running_cagr_periods=[2,3,4,5],
    plot_running_xirr=False,
    plot_rolling_returns_percentiles=True,
    rolling_percentiles_to_show=[0,5, 10, 25, 50, 75, 80,85, 90, 95,100],
    display_rolling_returns_table=False,
    interactive_cagr=True
)
# Out:
# ====================================================================================================
#  COMPARING 1 PORTFOLIOS
# ====================================================================================================
#  Unique indices needed: 1
#    - RAFI Fundamental High Liquidity Developed ex US Large Index
#
# 📂 Loading index data...
#
# ✅ Global common date grid: 1984-04-03 to 2026-03-20 (10853 days)
#
# [1/1] Processing: FunHighLiq-Dev-ex-US-L
# ------------------------------------------------------------
# ✅ Successfully processed: FunHighLiq-Dev-ex-US-L
#
# 📊 COMBINED SUMMARY - ALL PORTFOLIOS (COMMON DATES)
# ====================================================================================================
#                                       Date Range Total Trading Days Start Value End Value Total Return % CAGR % Annualized Volatility % Sharpe Ratio Max Drawdown % Max Drawdown Date SIP XIRR % SIP Return % SIP Invested Amt SIP Final Amt Positive Days % Negative Days % Max Daily Return % Min Daily Return % 3Y Rolling Avg % 3Y Rolling Median % 3Y Rolling Min % 3Y Rolling Max % 5Y Rolling Avg % 5Y Rolling Median % 5Y Rolling Min % 5Y Rolling Max % 7Y Rolling Avg % 7Y Rolling Median % 7Y Rolling Min % 7Y Rolling Max % 10Y Rolling Avg % 10Y Rolling Median % 10Y Rolling Min % 10Y Rolling Max % 2026 Return % 2025 Return % 2024 Return % 2023 Return % 2022 Return %
# FunHighLiq-Dev-ex-US-L  1984-04-04 to 2026-03-20              10852         1.0     85.22        8407.39  11.17                   15.17        0.506         -54.71        2009-03-09      10.1%      1279.38          5040000   69520543.47           53.57           45.72               7.95             -12.23            10.53                9.24           -15.72            55.12             9.48                8.26            -5.28            36.37             8.91                8.31            -0.81            25.38               8.8                 8.62              1.88             21.25      5.684252     41.544592      3.853112      21.21776      -7.41505
#
# 📈 Generating comparison plots...
# 📊 Precomputing rolling returns for all periods...
#    Computing 3Y rolling returns...
#    Computing 4Y rolling returns...
#    Computing 5Y rolling returns...
#    Computing 7Y rolling returns...
#    Computing 10Y rolling returns...
# ✅ Precomputation complete!
#
# ================================================================================
#  INTERACTIVE RUNNING CAGR PLOT
# ================================================================================
# Rolling periods available: [3, 4, 5, 7, 10]
# Use the slider below to select the rolling period
# --------------------------------------------------------------------------------
# interactive(children=(SelectionSlider(description='Rolling Period (years):', layout=Layout(width='500px'), opt…

# %% [markdown]
# # Intl ex US Portfolio (EM + Dev ex US)

# %%
# Define two portfolio options
portfolios_to_compare = [
    {
        'name': 'EM_Dev (50-50)',  
        'weights': [
            ('RAFI Fundamental High Liquidity Developed ex US Large Index', 0.25),
            ('RAFI Dynamic Multi-Factor Developed ex US Index', 0.25),
            ('RAFI Fundamental High Liquidity Emerging Markets Large Index', 0.5),
        ]
    },
    {
        'name': 'EM_Dev (60-40)',  
        'weights': [
            ('RAFI Fundamental High Liquidity Developed ex US Large Index', 0.20),
            ('RAFI Dynamic Multi-Factor Developed ex US Index', 0.2),
            ('RAFI Fundamental High Liquidity Emerging Markets Large Index', 0.6),
        ]
    },
    {
        'name': 'EM_Dev (30-70)',  
        'weights': [
            ('RAFI Fundamental High Liquidity Developed ex US Large Index', 0.35),
            ('RAFI Dynamic Multi-Factor Developed ex US Index', 0.35),
            ('RAFI Fundamental High Liquidity Emerging Markets Large Index', 0.3),
        ]
    },
        {
        'name': 'EM_Dev (70-30)',  
        'weights': [
            ('RAFI Fundamental High Liquidity Developed ex US Large Index', 0.15),
            ('RAFI Dynamic Multi-Factor Developed ex US Index', 0.15),
            ('RAFI Fundamental High Liquidity Emerging Markets Large Index', 0.7),
        ]
    },

    {
        'name': 'FunHighLiq-Dev-ex-US-L',
        'weights': [
            ('RAFI Fundamental High Liquidity Developed ex US Large Index', 1),
        ]
    },
    {
        'name': 'MultiFac Dev-ex-US',
        'weights': [
            ('RAFI Dynamic Multi-Factor Developed ex US Index', 1),
        ]
    },
    {
        'name': 'RAFIFunHighLiq-EM',
        'weights': [
            ('RAFI Fundamental High Liquidity Emerging Markets Large Index', 1),
        ]
    },
    # {
    #     'name': 'FunSel-EM-350',
    #     'weights': [
    #         ('RAFI Fundamental Select Emerging Markets 350 Index', 1),
    #     ]
    # },

]
# Run the comparison
summary = compare_portfolios(
    portfolios_to_compare,
    risk_free_rate=3.5,
    sip_amount=10000,
    show_plots=False,
    export_csv=False,
    search_path='.',          # where your CSV files are
    recursive=True,
    output_fname="example",
    # start_date=None,        # new
    # end_date=None
    # start_date='2011-01-01',
    # end_date='2010-12-31',        # new
    data_format='auto',
    plot_running_cagr=True,
    running_cagr_periods=[3,4,5,7,10],
    # running_cagr_periods=[2,3,4,5],
    plot_running_xirr=False,
    plot_rolling_returns_percentiles=False,
    rolling_percentiles_to_show=[0,5, 10, 25, 50, 75, 80,85, 90, 95,100],
    display_rolling_returns_table=False,
    interactive_cagr=True
)
# Out:
# ====================================================================================================
#  COMPARING 7 PORTFOLIOS
# ====================================================================================================
#  Unique indices needed: 3
#    - RAFI Dynamic Multi-Factor Developed ex US Index
#    - RAFI Fundamental High Liquidity Developed ex US Large Index
#    - RAFI Fundamental High Liquidity Emerging Markets Large Index
#
# 📂 Loading index data...
#
# ✅ Global common date grid: 1996-04-02 to 2026-03-20 (7750 days)
#
# [1/7] Processing: EM_Dev (50-50)
# ------------------------------------------------------------
# ✅ Successfully processed: EM_Dev (50-50)
#
# [2/7] Processing: EM_Dev (60-40)
# ------------------------------------------------------------
# ✅ Successfully processed: EM_Dev (60-40)
#
# [3/7] Processing: EM_Dev (30-70)
# ------------------------------------------------------------
# ✅ Successfully processed: EM_Dev (30-70)
#
# [4/7] Processing: EM_Dev (70-30)
# ------------------------------------------------------------
# ✅ Successfully processed: EM_Dev (70-30)
#
# [5/7] Processing: FunHighLiq-Dev-ex-US-L
# ------------------------------------------------------------
# ✅ Successfully processed: FunHighLiq-Dev-ex-US-L
#
# [6/7] Processing: MultiFac Dev-ex-US
# ------------------------------------------------------------
# ✅ Successfully processed: MultiFac Dev-ex-US
#
# [7/7] Processing: RAFIFunHighLiq-EM
# ------------------------------------------------------------
# ✅ Successfully processed: RAFIFunHighLiq-EM
#
# 📊 COMBINED SUMMARY - ALL PORTFOLIOS (COMMON DATES)
# ====================================================================================================
#                                       Date Range Total Return % CAGR % Annualized Volatility % Sharpe Ratio Max Drawdown % SIP XIRR % SIP Return % SIP Invested Amt SIP Final Amt Start Value End Value Positive Days % Negative Days % Max Daily Return % Min Daily Return % 3Y Rolling Avg % 3Y Rolling Median % 3Y Rolling Min % 3Y Rolling Max % 5Y Rolling Avg % 5Y Rolling Median % 5Y Rolling Min % 5Y Rolling Max % 7Y Rolling Avg % 7Y Rolling Median % 7Y Rolling Min % 7Y Rolling Max % 10Y Rolling Avg % 10Y Rolling Median % 10Y Rolling Min % 10Y Rolling Max % 2026 Return % 2025 Return % 2024 Return % 2023 Return % 2022 Return %
# EM_Dev (50-50)          1996-04-03 to 2026-03-20        1875.22  10.47                    16.2         0.43         -59.71     11.03%       601.11          3600000   25240089.49         1.0     19.71           55.34           44.66               9.64              -8.97            10.59                8.32           -12.42            48.76             10.2                8.09             -5.4            39.33            10.33                8.24            -0.94            26.07             10.32                 9.55              1.79             22.06       3.32369     32.746036     11.400417     18.874116    -11.053816
# EM_Dev (60-40)          1996-04-03 to 2026-03-20         2005.9  10.71                   16.69        0.432         -60.39      11.3%       639.09          3600000   26607131.18         1.0     21.01           55.18           44.82              10.62              -9.02            10.99                 8.5           -12.07            51.49             10.6                 8.2            -6.29            41.25            10.74                8.49            -1.03            27.82              10.7                 9.88              1.61             23.79      3.338614     32.098524      12.21704     18.872158    -11.349834
# EM_Dev (30-70)          1996-04-03 to 2026-03-20        1614.17   9.95                   15.38        0.419         -58.11     10.48%       529.52          3600000   22662704.41         1.0     17.12           55.22           44.78               7.39              -9.34             9.77                8.05           -13.25             43.2             9.37                8.03             -3.2            35.08             9.48                7.81            -0.71             22.4               9.5                 8.85              2.21             18.67      3.287086     34.361429      9.414244     18.878881    -10.324002
# EM_Dev (70-30)          1996-04-03 to 2026-03-20        2136.69  10.93                   17.23        0.431         -61.03     11.56%       678.73          3600000   28034376.84         1.0      22.3           55.09           44.91              11.52               -9.3            11.38                8.76           -11.76            54.13            10.98                8.43            -7.08            43.06            11.13                8.68            -1.11            29.52             11.07                10.22              1.44             25.56      3.351807     31.531314     12.942336     18.870421    -11.610803
# FunHighLiq-Dev-ex-US-L  1996-04-03 to 2026-03-20        1156.21   8.81                   15.72        0.338         -54.71      9.58%        429.3          3600000   19054712.17         1.0     12.57           53.19           45.94               7.95             -10.05             8.16                8.19           -15.72            34.13             7.63                 6.9            -5.63            25.93             7.58                7.59            -0.81            15.63              7.58                 7.33              1.69             13.95      5.684252     41.544592      3.853112      21.21776      -7.41505
# MultiFac Dev-ex-US      1996-04-03 to 2026-03-20        1290.65   9.18                   14.85        0.383         -54.93      9.65%        436.2          3600000   19303132.23         1.0      13.9           53.21           44.75               7.02             -10.25             8.68                8.19            -14.3            34.53             8.33                7.26            -4.47            28.41             8.45                7.93             0.31            17.45              8.52                 8.32              3.26              14.7      1.062783      35.27588       6.09018     16.999216     -9.676542
# RAFIFunHighLiq-EM       1996-04-03 to 2026-03-20        2529.72  11.53                   19.07        0.421         -63.27     12.35%       810.41          3600000   32774725.33         1.0     26.19           54.65           44.95              13.81              -10.0            12.52                9.23           -14.02            61.62            12.11                9.03             -9.0            48.21            12.26                9.17            -1.31            34.45             12.12                10.66              1.02             31.27       3.38357     30.185547     14.701448      18.86621    -12.236271
#
# 📈 Generating comparison plots...
# 📊 Precomputing rolling returns for all periods...
#    Computing 3Y rolling returns...
#    Computing 4Y rolling returns...
#    Computing 5Y rolling returns...
#    Computing 7Y rolling returns...
#    Computing 10Y rolling returns...
# ✅ Precomputation complete!
#
# ================================================================================
#  INTERACTIVE RUNNING CAGR PLOT
# ================================================================================
# Rolling periods available: [3, 4, 5, 7, 10]
# Use the slider below to select the rolling period
# --------------------------------------------------------------------------------
# interactive(children=(SelectionSlider(description='Rolling Period (years):', layout=Layout(width='500px'), opt…

# %% [markdown]
# # GARP RAFI US portfolio ??

# %%
# Define two portfolio options
portfolios_to_compare = [
        {        # with GARP
        'name': 'US LMS (50-25-25)',  
        'weights': [
            ('RAFI Fundamental High Liquidity US Small Index', 0.3),
            ('RAFI Dynamic Multi-Factor US Index', 0.18),
            ('RAFI Fundamental High Liquidity US Large Index', 0.18),
            ('MSCI USA Quality GARP Select Index', 0.35),
        ]
    },

    # {    # without GARP
    #     'name': 'US LMS (50-25-25)',  
    #     'weights': [
    #         ('RAFI Fundamental High Liquidity US Small Index', 0.3),
    #         ('RAFI Dynamic Multi-Factor US Index', 0.35),
    #         ('RAFI Fundamental High Liquidity US Large Index', 0.35),
    #     ]
    # },

    {
        'name': 'FunHiqhLiq-S',  
        'weights': [
            ('RAFI Fundamental High Liquidity US Small Index', 1),
        ]
    },
        {
        'name': 'Dyn-MultiFac',
        'weights': [
            ('RAFI Dynamic Multi-Factor US Index', 1),
        ]
    },
    {
        'name': 'FunHighLiq-L',
        'weights': [
            ('RAFI Fundamental High Liquidity US Large Index', 1),
        ]
    },

]
# Run the comparison
summary = compare_portfolios(
    portfolios_to_compare,
    risk_free_rate=3.5,
    sip_amount=10000,
    show_plots=False,
    export_csv=False,
    search_path='.',          # where your CSV files are
    recursive=True,
    output_fname="example",
    # start_date=None,        # new
    # end_date=None
    start_date='2016-01-01',
    # end_date='2010-01-01',        # new
    data_format='auto',
    plot_running_cagr=True,
    running_cagr_periods=[3,4,5,7,10],
    # running_cagr_periods=[2,3,4,5],
    plot_running_xirr=False,
    plot_rolling_returns_percentiles=True,
    rolling_percentiles_to_show=[0,5, 10, 25, 50, 75, 80,85, 90, 95,100],
    display_rolling_returns_table=False,
    interactive_cagr=True
)
# Out:
# ====================================================================================================
#  COMPARING 4 PORTFOLIOS
# ====================================================================================================
#  Unique indices needed: 4
#    - MSCI USA Quality GARP Select Index
#    - RAFI Dynamic Multi-Factor US Index
#    - RAFI Fundamental High Liquidity US Large Index
#    - RAFI Fundamental High Liquidity US Small Index
#
# 📂 Loading index data...
#
# ✅ Global common date grid: 2016-01-04 to 2026-03-30 (2574 days)
#
# [1/4] Processing: US LMS (50-25-25)
# ------------------------------------------------------------
# ✅ Successfully processed: US LMS (50-25-25)
#
# [2/4] Processing: FunHiqhLiq-S
# ------------------------------------------------------------
# ✅ Successfully processed: FunHiqhLiq-S
#
# [3/4] Processing: Dyn-MultiFac
# ------------------------------------------------------------
# ✅ Successfully processed: Dyn-MultiFac
#
# [4/4] Processing: FunHighLiq-L
# ------------------------------------------------------------
# ✅ Successfully processed: FunHighLiq-L
#
# 📊 COMBINED SUMMARY - ALL PORTFOLIOS (COMMON DATES)
# ====================================================================================================
#                                  Date Range Total Trading Days Start Value End Value Total Return % CAGR % Annualized Volatility % Sharpe Ratio Max Drawdown % Max Drawdown Date SIP XIRR % SIP Return % SIP Invested Amt SIP Final Amt Positive Days % Negative Days % Max Daily Return % Min Daily Return % 3Y Rolling Avg % 3Y Rolling Median % 3Y Rolling Min % 3Y Rolling Max % 5Y Rolling Avg % 5Y Rolling Median % 5Y Rolling Min % 5Y Rolling Max % 7Y Rolling Avg % 7Y Rolling Median % 7Y Rolling Min % 7Y Rolling Max % 10Y Rolling Avg % 10Y Rolling Median % 10Y Rolling Min % 10Y Rolling Max % 2026 Return % 2025 Return % 2024 Return % 2023 Return % 2022 Return %
# US LMS (50-25-25)  2016-01-05 to 2026-03-30               2573        1.01      3.56         252.25   13.1                   19.27        0.498         -38.21        2020-03-23     14.63%       116.98          1230000    2668891.03           55.03           44.97               9.89             -12.73            12.69               12.26             -3.9            27.25            13.62               14.01             7.88            23.23            12.58               12.36             9.67            17.17             14.67                14.86             13.12              15.7     -4.318426     16.618084     21.734107     23.865214    -16.743285
# FunHiqhLiq-S       2016-01-05 to 2026-03-30               2573         1.0      2.95         194.81  11.15                   21.87         0.35         -43.57        2020-03-23     11.66%        84.67          1230000    2271433.36           52.82           47.14              10.08             -13.49            10.01               10.29            -8.75            28.56            11.47                11.0             4.89            21.52             9.91                9.87             6.24            14.71             12.62                12.94             11.03             13.89     -0.385966      8.156758     10.084049     20.363595    -17.211184
# Dyn-MultiFac       2016-01-05 to 2026-03-30               2573         1.0      3.33         231.18  12.42                   16.97        0.525         -35.92        2020-03-23     14.05%       110.27          1230000     2586327.8            54.8           45.16               9.08             -11.95            11.73               11.32            -3.63            23.99            12.51               13.02             7.15            22.33            11.67               11.67             9.36            15.65             13.45                13.65             12.35             14.36       0.31433     16.203691     20.661007     13.012994     -6.090882
# FunHighLiq-L       2016-01-05 to 2026-03-30               2573         1.0      3.75         274.59  13.78                    18.0        0.571         -37.99        2020-03-23     15.27%       124.72          1230000    2764019.37           53.67           46.29               9.54             -11.75             13.2               12.99            -5.03            29.75            14.39               14.73             9.35            25.24            13.15               12.88            10.96            17.26             14.96                15.14             13.68             15.91     -0.060368     17.568523     16.512375     18.775897     -4.204365
#
# 📈 Generating comparison plots...
# 📊 Precomputing rolling returns for all periods...
#    Computing 3Y rolling returns...
#    Computing 4Y rolling returns...
#    Computing 5Y rolling returns...
#    Computing 7Y rolling returns...
#    Computing 10Y rolling returns...
# ✅ Precomputation complete!
#
# ================================================================================
#  INTERACTIVE RUNNING CAGR PLOT
# ================================================================================
# Rolling periods available: [3, 4, 5, 7, 10]
# Use the slider below to select the rolling period
# --------------------------------------------------------------------------------
# interactive(children=(SelectionSlider(description='Rolling Period (years):', layout=Layout(width='500px'), opt…

# %% [markdown]
# # Composite Intl Portfolio

# %%
# Define two portfolio options
portfolios_to_compare = [
        {    # without GARP
        'name': 'Intl (50-25-25)',  # US:Em:Dev
        'weights': [
            # US
            ('RAFI Fundamental High Liquidity US Small Index', 0.15),
            ('RAFI Dynamic Multi-Factor US Index', 0.175),
            ('RAFI Fundamental High Liquidity US Large Index', 0.175),
            # Em
            ('RAFI Fundamental High Liquidity Emerging Markets Large Index', 0.25),
            # Dev ex US
            ('RAFI Fundamental High Liquidity Developed ex US Large Index', 0.125),
            ('RAFI Dynamic Multi-Factor Developed ex US Index', 0.125),
        ]
    },
    # {    # without GARP
    #     'name': 'Intl (50-15-35)',  # US:Em:Dev
    #     'weights': [
    #         # US
    #         ('RAFI Fundamental High Liquidity US Small Index', 0.15),
    #         ('RAFI Dynamic Multi-Factor US Index', 0.175),
    #         ('RAFI Fundamental High Liquidity US Large Index', 0.175),
    #         # Em
    #         ('RAFI Fundamental High Liquidity Emerging Markets Large Index', 0.15),
    #         # Dev ex US
    #         ('RAFI Fundamental High Liquidity Developed ex US Large Index', 0.175),
    #         ('RAFI Dynamic Multi-Factor Developed ex US Index', 0.175),
    #     ]
    # },
        {    # without GARP
        'name': 'Intl (33-33-33)',  # US:Em:Dev
        'weights': [
            # US
            ('RAFI Fundamental High Liquidity US Small Index', 0.1),
            ('RAFI Dynamic Multi-Factor US Index', 0.1155),
            ('RAFI Fundamental High Liquidity US Large Index', 0.1155),
            # Em
            ('RAFI Fundamental High Liquidity Emerging Markets Large Index', 0.33),
            # Dev ex US
            ('RAFI Fundamental High Liquidity Developed ex US Large Index', 0.165),
            ('RAFI Dynamic Multi-Factor Developed ex US Index', 0.165),
        ]
    },
        {    # without GARP
        'name': 'Intl (40-30-30)',  # US:Em:Dev
        'weights': [
            # US
            ('RAFI Fundamental High Liquidity US Small Index', 0.12),
            ('RAFI Dynamic Multi-Factor US Index', 0.14),
            ('RAFI Fundamental High Liquidity US Large Index', 0.14),
            # Em
            ('RAFI Fundamental High Liquidity Emerging Markets Large Index', 0.30),
            # Dev ex US
            ('RAFI Fundamental High Liquidity Developed ex US Large Index', 0.15),
            ('RAFI Dynamic Multi-Factor Developed ex US Index', 0.15),
        ]
    },

    {    # without GARP
        'name': 'US LMS (50-25-25)',  
        'weights': [
            ('RAFI Fundamental High Liquidity US Small Index', 0.3),
            ('RAFI Dynamic Multi-Factor US Index', 0.35),
            ('RAFI Fundamental High Liquidity US Large Index', 0.35),
        ]
    },
    {
        'name': 'EM_Dev (50-50)',  
        'weights': [
            ('RAFI Fundamental High Liquidity Developed ex US Large Index', 0.25),
            ('RAFI Dynamic Multi-Factor Developed ex US Index', 0.25),
            ('RAFI Fundamental High Liquidity Emerging Markets Large Index', 0.50),
        ]
    },

    # {
    #     'name': 'US_HiqhLiq-S',  
    #     'weights': [
    #         ('RAFI Fundamental High Liquidity US Small Index', 1),
    #     ]
    # },
    #     {
    #     'name': 'US_Dyn-MultiFac',
    #     'weights': [
    #         ('RAFI Dynamic Multi-Factor US Index', 1),
    #     ]
    # },
    # {
    #     'name': 'US_HighLiq-L',
    #     'weights': [
    #         ('RAFI Fundamental High Liquidity US Large Index', 1),
    #     ]
    # },


    # {
    #     'name': 'Dev_HighLiq-L',
    #     'weights': [
    #         ('RAFI Fundamental High Liquidity Developed ex US Large Index', 1),
    #     ]
    # },
    # {
    #     'name': 'Dev_MultiFac',
    #     'weights': [
    #         ('RAFI Dynamic Multi-Factor Developed ex US Index', 1),
    #     ]
    # },
    # {
    #     'name': 'EM_FunHighLiq',
    #     'weights': [
    #         ('RAFI Fundamental High Liquidity Emerging Markets Large Index', 1),
    #     ]
    # },

]
# Run the comparison
summary = compare_portfolios(
    portfolios_to_compare,
    risk_free_rate=3.5,
    sip_amount=2125,
    show_plots=False,
    export_csv=False,
    search_path='.',          # where your CSV files are
    recursive=True,
    output_fname="example",
    # start_date=None,        # new
    # end_date=None
    # start_date='2010-01-01',
    # end_date='2010-01-01',        # new
    data_format='auto',
    plot_running_cagr=True,
    running_cagr_periods=[3,4,5,7,10],
    # running_cagr_periods=[2,3,4,5],
    plot_running_xirr=False,
    plot_rolling_returns_percentiles=True,
    rolling_percentiles_to_show=[0,5, 10, 25, 50, 75, 80,85, 90, 95,100],
    display_rolling_returns_table=False,
    interactive_cagr=True
)
# Out:
# ====================================================================================================
#  COMPARING 5 PORTFOLIOS
# ====================================================================================================
#  Unique indices needed: 6
#    - RAFI Dynamic Multi-Factor Developed ex US Index
#    - RAFI Dynamic Multi-Factor US Index
#    - RAFI Fundamental High Liquidity Developed ex US Large Index
#    - RAFI Fundamental High Liquidity Emerging Markets Large Index
#    - RAFI Fundamental High Liquidity US Large Index
#    - RAFI Fundamental High Liquidity US Small Index
#
# 📂 Loading index data...
#
# ✅ Global common date grid: 1996-04-02 to 2026-03-20 (7536 days)
#
# [1/5] Processing: Intl (50-25-25)
# ------------------------------------------------------------
# ✅ Successfully processed: Intl (50-25-25)
#
# [2/5] Processing: Intl (33-33-33)
# ------------------------------------------------------------
# ✅ Successfully processed: Intl (33-33-33)
#
# [3/5] Processing: Intl (40-30-30)
# ------------------------------------------------------------
# ✅ Successfully processed: Intl (40-30-30)
#
# [4/5] Processing: US LMS (50-25-25)
# ------------------------------------------------------------
# ✅ Successfully processed: US LMS (50-25-25)
#
# [5/5] Processing: EM_Dev (50-50)
# ------------------------------------------------------------
# ✅ Successfully processed: EM_Dev (50-50)
#
# 📊 COMBINED SUMMARY - ALL PORTFOLIOS (COMMON DATES)
# ====================================================================================================
#                                  Date Range Total Return % CAGR % Annualized Volatility % Sharpe Ratio Max Drawdown % SIP XIRR % SIP Return % SIP Invested Amt SIP Final Amt Start Value End Value Positive Days % Negative Days % Max Daily Return % Min Daily Return % 3Y Rolling Avg % 3Y Rolling Median % 3Y Rolling Min % 3Y Rolling Max % 5Y Rolling Avg % 5Y Rolling Median % 5Y Rolling Min % 5Y Rolling Max % 7Y Rolling Avg % 7Y Rolling Median % 7Y Rolling Min % 7Y Rolling Max % 10Y Rolling Avg % 10Y Rolling Median % 10Y Rolling Min % 10Y Rolling Max % 2026 Return % 2025 Return % 2024 Return % 2023 Return % 2022 Return %
# Intl (50-25-25)    1996-04-03 to 2026-03-20        2456.47  11.43                   15.61        0.508         -56.61     11.58%       680.92           765000    5974027.35         1.0     25.55            55.0            45.0                8.7              -9.87            11.37               11.09           -13.76            37.68            11.13               10.58            -0.86             31.6            11.13               10.43             2.07            19.26             11.05                10.65              4.66              16.7      0.900729      20.47071     13.872586     18.075464    -10.450542
# Intl (33-33-33)    1996-04-03 to 2026-03-20        2264.25  11.13                   15.29        0.499         -57.56      11.4%       654.45           765000    5771508.64        0.99     23.41           54.92           45.08                8.1              -9.62            11.21                10.3           -13.14            41.05            10.95               10.03            -0.81            34.74            10.99                 9.8             1.22            21.27              10.9                10.45               3.6             17.84      1.256849     23.772931     13.223698     18.286571    -10.620611
# Intl (40-30-30)    1996-04-03 to 2026-03-20        2340.37  11.25                   15.36        0.505         -57.16     11.47%       664.89           765000    5851435.48         1.0     24.39           54.69           45.31               8.34              -9.72            11.27               10.63           -13.38            39.67            11.02               10.25            -0.83            33.47            11.05               10.08             1.57            20.46             10.96                 10.6              4.02             17.35      1.108945     22.379994     13.503045     18.194546    -10.540697
# US LMS (50-25-25)  1996-04-03 to 2026-03-20        3035.86  12.19                    18.8        0.462         -54.06     12.08%       762.44           765000    6597685.76         1.0      31.4           54.53           45.47              10.62             -12.48            11.85               11.89           -16.15            36.05            11.65               11.99             -5.1            30.69            11.51               11.55            -0.87             22.6             11.47                11.44              3.51             19.67      0.100181     13.660774     15.212575     17.644543    -10.123698
# EM_Dev (50-50)     1996-04-03 to 2026-03-20        1875.22  10.47                   16.57        0.421         -59.71     11.03%       601.19           765000    5364072.95         1.0     19.71           55.28           44.72               9.64              -8.97             10.9                8.13           -11.92             49.3            10.53                8.19            -5.22            41.78            10.69                8.53            -0.69            25.79             10.54                 9.77              1.36             20.71      2.202571     33.510347     11.400417     18.874116    -11.053816
#
# 📈 Generating comparison plots...
# 📊 Precomputing rolling returns for all periods...
#    Computing 3Y rolling returns...
#    Computing 4Y rolling returns...
#    Computing 5Y rolling returns...
#    Computing 7Y rolling returns...
#    Computing 10Y rolling returns...
# ✅ Precomputation complete!
#
# ================================================================================
#  INTERACTIVE RUNNING CAGR PLOT
# ================================================================================
# Rolling periods available: [3, 4, 5, 7, 10]
# Use the slider below to select the rolling period
# --------------------------------------------------------------------------------
# interactive(children=(SelectionSlider(description='Rolling Period (years):', layout=Layout(width='500px'), opt…
