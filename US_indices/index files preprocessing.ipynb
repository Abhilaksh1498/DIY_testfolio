# %% [markdown]
# ### MSCI Indices

# %%
import pandas as pd

fname_prefix = "MSCI EAFE Growth Index"
df = pd.read_excel(f"{fname_prefix}.xlsx", skiprows=5, usecols=[0,1])
df.to_csv(f"{fname_prefix}.csv", index=False)

# %% [markdown]
# ### RAFI Indices

# %%
import pandas as pd

df = pd.read_excel(f"RAFI-Indices-Returns.xlsx", skiprows=9)
df = df.iloc[:, 1:]
df.head()
# Out:
#             Unnamed: 1 RAFI Fundamental Select Developed ex US 1000 Index  \
# 0                  NaN                                           RAFSDXUT
# 1                 Date                                      Total Returns
# 2  2026-03-20 00:00:00                                          -0.010183
# 3  2026-03-19 00:00:00                                          -0.021473
# 4  2026-03-18 00:00:00                                           0.007738
#
#     Unnamed: 3     Unnamed: 4  \
# 0          NaN            NaN
# 1  Net Returns  Price Returns
# 2    -0.010199      -0.010264
# 3    -0.021482      -0.021735
# 4     0.007736       0.007729
#
#   RAFI Fundamental Select Developed ex US 1500 Index   Unnamed: 6  \
# 0                                           RAFSDXST          NaN
# 1                                      Total Returns  Net Returns
# 2                                          -0.006498    -0.006538
# 3                                           -0.02257    -0.022591
# 4                                           0.007347     0.007314
#
#       Unnamed: 7 RAFI Fundamental Select Emerging Markets 350 Index  \
# 0            NaN                                           RAFSEMMT
# 1  Price Returns                                      Total Returns
# 2      -0.006628                                          -0.012213
# 3      -0.022748                                          -0.019379
# 4       0.007222                                           0.000738
#
#     Unnamed: 9    Unnamed: 10  ...    Unnamed: 13  \
# 0          NaN            NaN  ...            NaN
# 1  Net Returns  Price Returns  ...  Price Returns
# 2    -0.012229      -0.012301  ...      -0.011108
# 3    -0.019389      -0.019427  ...      -0.018907
# 4     0.000714       0.000613  ...       0.001623
#
#   RAFI Fundamental Emerging Markets Index  Unnamed: 15    Unnamed: 16  \
# 0                                 RAFIEMT          NaN            NaN
# 1                           Total Returns  Net Returns  Price Returns
# 2                               -0.007694    -0.007701      -0.007751
# 3                               -0.025461    -0.025476      -0.025522
# 4                                0.018649     0.018629       0.018501
#
#   RAFI Dynamic Multi-Factor Developed ex US Index  Unnamed: 18    Unnamed: 19  \
# 0                                        RADMFXUT          NaN            NaN
# 1                                   Total Returns  Net Returns  Price Returns
# 2                                       -0.012134    -0.012162      -0.012243
# 3                                       -0.021127    -0.021137      -0.021454
# 4                                        0.000442     0.000437       0.000421
#
#   RAFI Dynamic Multi-Factor Emerging Markets Index  Unnamed: 21    Unnamed: 22
# 0                                         RADMFEMT          NaN            NaN
# 1                                    Total Returns  Net Returns  Price Returns
# 2                                        -0.004852    -0.004863      -0.004915
# 3                                        -0.023642     -0.02367      -0.023775
# 4                                         0.010965     0.010917       0.010644
#
# [5 rows x 22 columns]

# %%
date_col = df.iloc[2:,0]

indices = []
for col in df.columns[1:]:
    if col.__contains__("Index"):
        indices.append(col)
indices
# Out:
# ['RAFI Fundamental Select Developed ex US 1000 Index',
#  'RAFI Fundamental Select Developed ex US 1500 Index',
#  'RAFI Fundamental Select Emerging Markets 350 Index',
#  'RAFI Fundamental Developed ex US Index',
#  'RAFI Fundamental Emerging Markets Index',
#  'RAFI Dynamic Multi-Factor Developed ex US Index',
#  'RAFI Dynamic Multi-Factor Emerging Markets Index']

# %%
df = df.loc[2:, indices]
df.index = date_col
df.index.name = 'Date'
df.head()

for i in range(len(indices)):
    df[indices[i]].dropna().to_csv(f"{indices[i]}.csv", index=True)
# Out:
# /Users/abhilaksh/anaconda3/lib/python3.13/site-packages/pandas/core/indexes/base.py:7631: FutureWarning: Dtype inference on a pandas object (Series, Index, ExtensionArray) is deprecated. The Index constructor will keep the original dtype in the future. Call `infer_objects` on the result to get the old behavior.
#   return Index(index_like, name=name, copy=copy)

# %%
df[indices[2]][df[indices[2]] == 0]
# Out:
# Date
# 2024-05-01    0
# 2024-02-13    0
# 2024-02-12    0
# 2024-01-01    0
# 2023-12-25    0
# 2023-05-01    0
# 2023-04-07    0
# 2023-01-02    0
# 2022-05-02    0
# 2022-04-15    0
# 2021-04-02    0
# 2020-12-25    0
# 2020-05-01    0
# 2020-04-10    0
# 2020-01-01    0
# 2019-12-25    0
# 2019-05-01    0
# 2019-04-19    0
# 2018-12-25    0
# 2018-05-01    0
# 2017-12-25    0
# 2017-05-01    0
# 2017-01-02    0
# 2016-05-02    0
# 2016-02-08    0
# 2015-05-01    0
# 2014-05-01    0
# 2013-05-01    0
# 2013-03-31    0
# 2012-05-01    0
# 2011-05-02    0
# 2010-02-15    0
# 2009-05-01    0
# 2009-01-26    0
# 2008-05-01    0
# 2007-05-01    0
# 2007-02-19    0
# 2006-05-01    0
# 2003-05-01    0
# 2002-05-01    0
# 2002-03-31    0
# 2002-02-12    0
# 2001-05-01    0
# 2001-01-25    0
# 2000-12-25    0
# 2000-05-01    0
# 2000-01-03    0
# 1998-05-01    0
# 1998-01-02    0
# 1997-05-01    0
# 1996-05-01    0
# Name: RAFI Fundamental Select Emerging Markets 350 Index, dtype: object
