# %% [markdown]
# ### MSCI Indices

# %%
import pandas as pd

fname_prefix = "MSCI EAFE Growth Index"
df = pd.read_excel(f"{fname_prefix}.xlsx", skiprows=5, usecols=[0,1])
df.to_csv(f"{fname_prefix}.csv", index=False)

# %% [markdown]
# ### RAFI Indices

# %%
import pandas as pd

df = pd.read_excel(f"RAFI-HighLiq-Index-Returns.xlsx", skiprows=9)
df = df.iloc[:, 1:]
df.head()
# Out:
#             Unnamed: 1  \
# 0                  NaN
# 1                 Date
# 2  2026-03-20 00:00:00
# 3  2026-03-19 00:00:00
# 4  2026-03-18 00:00:00
#
#   RAFI Fundamental High Liquidity Developed ex US Large Index   Unnamed: 3  \
# 0                                           RAHLXULT                   NaN
# 1                                      Total Returns           Net Returns
# 2                                           -0.01029              -0.01031
# 3                                          -0.020989             -0.021002
# 4                                           0.007834              0.007837
#
#       Unnamed: 4 RAFI Fundamental High Liquidity Developed ex US Small Index  \
# 0            NaN                                           RAHLXUST
# 1  Price Returns                                      Total Returns
# 2      -0.010387                                          -0.004897
# 3      -0.021222                                          -0.022394
# 4       0.007836                                           0.009062
#
#     Unnamed: 6     Unnamed: 7  \
# 0          NaN            NaN
# 1  Net Returns  Price Returns
# 2     -0.01031      -0.010387
# 3    -0.021002      -0.021222
# 4     0.007837       0.007836
#
#   RAFI Fundamental High Liquidity Emerging Markets Large Index   Unnamed: 9  \
# 0                                           RAHLEMLT                    NaN
# 1                                      Total Returns            Net Returns
# 2                                          -0.012034               -0.01205
# 3                                          -0.017628              -0.017632
# 4                                          -0.000345              -0.000368
#
#      Unnamed: 10
# 0            NaN
# 1  Price Returns
# 2      -0.012119
# 3       -0.01766
# 4      -0.000496

# %%
date_col = df.iloc[2:,0]

indices = []
for col in df.columns[1:]:
    if col.__contains__("Index"):
        indices.append(col)
indices
# Out:
# ['RAFI Fundamental High Liquidity Developed ex US Large Index',
#  'RAFI Fundamental High Liquidity Developed ex US Small Index',
#  'RAFI Fundamental High Liquidity Emerging Markets Large Index']

# %%
df = df.loc[2:, indices]
df.index = date_col
df.index.name = 'Date'
df.head()

for i in range(len(indices)):
    df[indices[i]].dropna().to_csv(f"{indices[i]}.csv", index=True)
# Out:
# /Users/abhilaksh/anaconda3/lib/python3.13/site-packages/pandas/core/indexes/base.py:7631: FutureWarning: Dtype inference on a pandas object (Series, Index, ExtensionArray) is deprecated. The Index constructor will keep the original dtype in the future. Call `infer_objects` on the result to get the old behavior.
#   return Index(index_like, name=name, copy=copy)

# %%
df[indices[2]][df[indices[2]] == 0]
# Out:
# Date
# 2024-05-01    0
# 2024-02-13    0
# 2024-02-12    0
# 2024-01-01    0
# 2023-12-25    0
# 2023-05-01    0
# 2023-04-07    0
# 2023-01-02    0
# 2022-05-02    0
# 2022-04-15    0
# 2021-04-02    0
# 2020-12-25    0
# 2020-05-01    0
# 2020-04-10    0
# 2020-01-01    0
# 2019-12-25    0
# 2019-05-01    0
# 2019-04-19    0
# 2018-12-25    0
# 2018-05-01    0
# 2017-12-25    0
# 2017-05-01    0
# 2017-01-02    0
# 2016-05-02    0
# 2016-02-08    0
# 2015-05-01    0
# 2014-05-01    0
# 2013-05-01    0
# 2013-03-31    0
# 2012-05-01    0
# 2011-05-02    0
# 2010-02-15    0
# 2009-05-01    0
# 2009-01-26    0
# 2008-05-01    0
# 2007-05-01    0
# 2007-02-19    0
# 2006-05-01    0
# 2003-05-01    0
# 2002-05-01    0
# 2002-03-31    0
# 2002-02-12    0
# 2001-05-01    0
# 2001-01-25    0
# 2000-12-25    0
# 2000-05-01    0
# 2000-01-03    0
# 1998-05-01    0
# 1998-01-02    0
# 1997-05-01    0
# 1996-05-01    0
# Name: RAFI Fundamental Select Emerging Markets 350 Index, dtype: object
