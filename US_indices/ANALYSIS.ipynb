# %% [markdown]
# ### Portfolio constituent options
# - "NIFTY500 VALUE 50",
# - "NIFTY500 MULTICAP MOMENTUM QUALITY 50",
# - "NIFTY500 MOMENTUM 50",
# - "NIFTY200 MOMENTUM 30",
# - "NIFTY TOTAL MARKET MOMENTUM QUALITY 50",
# - "NIFTY MIDSMALLCAP400 MOMENTUM QUALITY 100",
# - "NIFTY MIDCAP150 MOMENTUM 50",
# - "NIFTY SMALLCAP250 MOMENTUM QUALITY 100",

# %% [markdown]
# # MSCI USA Quality GARP Select Index

# %% [markdown]
# ## Lost Decade

# %%
import composite_portfolio_analysis_Buy_and_Hold as cpa
from importlib import reload
reload(cpa)

from composite_portfolio_analysis_Buy_and_Hold import compare_portfolios


# Define two portfolio options
portfolios_to_compare = [
    # {
    #     'name': 'MSCI_USA_GARP',
    #     'weights': [
    #         ('MSCI USA Quality GARP Select Index Gross', 1),
    #     ]
    # },
        {
        'name': 'MSCI_USA_Value_exposure_Select',
        'weights': [
            ('MSCI USA Value Exposure Select Index', 1),
        ]
    },
            {
        'name': 'MSCI_USA_Enhanced_Value',
        'weights': [
            ('MSCI USA Enhanced Value Index', 1),
        ]
    },
    {
        'name': 'MSCI_USA_Enhanced_Value_Capped',
        'weights': [
            ('MSCI USA Enhanced Value Capped Index', 1),
        ]
    },
       {
        'name': 'MSCI_USA_Prime_Value',
        'weights': [
            ('MSCI USA Prime Value Index', 1),
        ]
    },
    {
        'name': 'MSCI_ACWI_ex_USA',
        'weights': [
            ('MSCI ACWI ex USA Index', 1),
        ]
    },

]
# Run the comparison
summary = compare_portfolios(
    portfolios_to_compare,
    risk_free_rate=3.5,
    sip_amount=10000,
    show_plots=False,
    export_csv=True,
    search_path='.',          # where your CSV files are
    recursive=False,
    output_fname="example",
    # start_date=None,        # new
    # end_date=None
    # start_date='2011-01-01',
    end_date='2010-12-31', 
    # plot_running_cagr=False,
    # rolling_periods=3
)
# Out:
# ...
#  COMPARING 5 PORTFOLIOS
# ...
#  Unique indices needed: 5
#    - MSCI ACWI ex USA Index
#    - MSCI USA Enhanced Value Capped Index
#    - MSCI USA Enhanced Value Index
#    - MSCI USA Prime Value Index
#    - MSCI USA Value Exposure Select Index
#
# 📂 Loading index data...
#
# ✅ Global common date grid: 1998-12-31 to 2010-12-31 (3127 days)
#
# [1/5] Processing: MSCI_USA_Value_exposure_Select
# ------------------------------------------------------------
#    📁 Exported: MSCI_USA_Value_exposure_Select_data.csv
# ✅ Successfully processed: MSCI_USA_Value_exposure_Select
#
# [2/5] Processing: MSCI_USA_Enhanced_Value
# ------------------------------------------------------------
#    📁 Exported: MSCI_USA_Enhanced_Value_data.csv
# ✅ Successfully processed: MSCI_USA_Enhanced_Value
#
# [3/5] Processing: MSCI_USA_Enhanced_Value_Capped
# ------------------------------------------------------------
#    📁 Exported: MSCI_USA_Enhanced_Value_Capped_data.csv
# ...

# %%
import composite_portfolio_analysis_Buy_and_Hold as cpa
from importlib import reload
reload(cpa)

from composite_portfolio_analysis_Buy_and_Hold import compare_portfolios


# Define two portfolio options
portfolios_to_compare = [
    # {
    #     'name': 'MSCI_USA_GARP',
    #     'weights': [
    #         ('MSCI USA Quality GARP Select Index Gross', 1),
    #     ]
    # },
       {
        'name': 'MSCI_USA_Prime_Value',
        'weights': [
            ('MSCI USA Prime Value Index', 1),
        ]
    },
    {
        'name': 'MSCI_World_ex_USA',
        'weights': [
            ('MSCI World ex USA Index', 1),
        ]
    },
    {
        'name': 'MSCI_EM_Index',
        'weights': [
            ('MSCI EM Index', 1),
        ]
    },
    {
        'name': 'MSCI_EM_mom_Index',
        'weights': [
            ('MSCI EM Momentum Index', 1),
        ]
    },
        {
        'name': 'MSCI_EM_Quality_Index',
        'weights': [
            ('MSCI EM Quality Index', 1),
        ]
    },
    #     {
    #     'name': 'MSCI_Europe_Quality_Index',
    #     'weights': [
    #         ('MSCI Europe Quality Index', 1),
    #     ]
    # },
    {
        'name': 'MSCI_Emerging_Markets_Quality_Factor_Select_Index',
        'weights': [
            ('MSCI Emerging Markets Quality Factor Select Index', 1),
        ]
    },

]
# Run the comparison
summary = compare_portfolios(
    portfolios_to_compare,
    risk_free_rate=3.5,
    sip_amount=10000,
    show_plots=False,
    export_csv=True,
    search_path='.',          # where your CSV files are
    recursive=False,
    output_fname="example",
    # start_date=None,        # new
    # end_date=None
    # start_date='2011-01-01',
    # end_date='2010-12-31',        # new

)
# Out:
# ...
#  COMPARING 6 PORTFOLIOS
# ...
#  Unique indices needed: 6
#    - MSCI EM Index
#    - MSCI EM Momentum Index
#    - MSCI EM Quality Index
#    - MSCI Emerging Markets Quality Factor Select Index
#    - MSCI USA Prime Value Index
#    - MSCI World ex USA Index
#
# 📂 Loading index data...
#
# ✅ Global common date grid: 2000-05-31 to 2026-03-02 (6673 days)
#
# [1/6] Processing: MSCI_USA_Prime_Value
# ------------------------------------------------------------
#    📁 Exported: MSCI_USA_Prime_Value_data.csv
# ✅ Successfully processed: MSCI_USA_Prime_Value
#
# [2/6] Processing: MSCI_World_ex_USA
# ------------------------------------------------------------
#    📁 Exported: MSCI_World_ex_USA_data.csv
# ✅ Successfully processed: MSCI_World_ex_USA
#
# [3/6] Processing: MSCI_EM_Index
# ------------------------------------------------------------
#    📁 Exported: MSCI_EM_Index_data.csv
# ✅ Successfully processed: MSCI_EM_Index
#
# [4/6] Processing: MSCI_EM_mom_Index
# ...

# %%
import composite_portfolio_analysis_Buy_and_Hold as cpa
from importlib import reload
reload(cpa)

from composite_portfolio_analysis_Buy_and_Hold import compare_portfolios


# Define two portfolio options
portfolios_to_compare = [
    # {
    #     'name': 'MSCI_USA_GARP',
    #     'weights': [
    #         ('MSCI USA Quality GARP Select Index Gross', 1),
    #     ]
    # },
       {
        'name': 'MSCI_EAFE',
        'weights': [
            ('MSCI EAFE Index', 1),
        ]
    },
    {
        'name': 'MSCI_EAFE_Value',
        'weights': [
            ('MSCI EAFE Value Index', 1),
        ]
    },
    {
        'name': 'MSCI_EAFE_Growth',
        'weights': [
            ('MSCI EAFE Growth Index', 1),
        ]
    },
    {
        'name': 'MSCI_EM_mom',
        'weights': [
            ('MSCI EM Momentum Index', 1),
        ]
    },
        {
        'name': 'MSCI_EM_Quality',
        'weights': [
            ('MSCI EM Quality Index', 1),
        ]
    },
        {
        'name': 'MSCI_EM',
        'weights': [
            ('MSCI EM Index', 1),
        ]
    },
    {
        'name': 'MSCI_EM_Quality_Factor_Select',
        'weights': [
            ('MSCI Emerging Markets Quality Factor Select Index', 1),
        ]
    },

]
# Run the comparison
summary = compare_portfolios(
    portfolios_to_compare,
    risk_free_rate=3.5,
    sip_amount=10000,
    show_plots=False,
    export_csv=True,
    search_path='.',          # where your CSV files are
    recursive=False,
    output_fname="example",
    # start_date=None,        # new
    # end_date=None
    start_date='2011-01-01',
    # end_date='2010-12-31',        # new

)
# Out:
# ...
#  COMPARING 7 PORTFOLIOS
# ...
#  Unique indices needed: 7
#    - MSCI EAFE Growth Index
#    - MSCI EAFE Index
#    - MSCI EAFE Value Index
#    - MSCI EM Index
#    - MSCI EM Momentum Index
#    - MSCI EM Quality Index
#    - MSCI Emerging Markets Quality Factor Select Index
#
# 📂 Loading index data...
#
# ✅ Global common date grid: 2011-01-03 to 2026-03-06 (3914 days)
#
# [1/7] Processing: MSCI_EAFE
# ------------------------------------------------------------
#    📁 Exported: MSCI_EAFE_data.csv
# ✅ Successfully processed: MSCI_EAFE
#
# [2/7] Processing: MSCI_EAFE_Value
# ------------------------------------------------------------
#    📁 Exported: MSCI_EAFE_Value_data.csv
# ✅ Successfully processed: MSCI_EAFE_Value
#
# [3/7] Processing: MSCI_EAFE_Growth
# ------------------------------------------------------------
#    📁 Exported: MSCI_EAFE_Growth_data.csv
# ✅ Successfully processed: MSCI_EAFE_Growth
#
# [4/7] Processing: MSCI_EM_mom
# ...

# %% [markdown]
# # RAFI Indices

# %%
import composite_portfolio_analysis_Buy_and_Hold as cpa
from importlib import reload
reload(cpa)

from composite_portfolio_analysis_Buy_and_Hold import compare_portfolios


# Define two portfolio options
portfolios_to_compare = [
    # {
    #     'name': 'MSCI_USA_GARP',
    #     'weights': [
    #         ('MSCI USA Quality GARP Select Index Gross', 1),
    #     ]
    # },
       {
        'name': 'MF Dev-ex-US',
        'weights': [
            ('RAFI Dynamic Multi-Factor Developed ex US Index', 1),
        ]
    },
    {
        'name': 'MF-EM',
        'weights': [
            ('RAFI Dynamic Multi-Factor Emerging Markets Index', 1),
        ]
    },
    {
        'name': 'Fun-Dev-ex-US',
        'weights': [
            ('RAFI Fundamental Developed ex US Index', 1),
        ]
    },
    {
        'name': 'Fun-EM',
        'weights': [
            ('RAFI Fundamental Emerging Markets Index', 1),
        ]
    },
        {
        'name': 'MSCI_EM_Quality',
        'weights': [
            ('MSCI EM Quality Index', 1),
        ]
    },
        {
        'name': 'FunSel-Dev-ex-US-1000',
        'weights': [
            ('RAFI Fundamental Select Developed ex US 1000 Index', 1),
        ]
    },
    {
        'name': 'FunSel-Dev-ex-US-1500',
        'weights': [
            ('RAFI Fundamental Select Developed ex US 1500 Index', 1),
        ]
    },
    {
        'name': 'FunSel-EM-350',
        'weights': [
            ('RAFI Fundamental Select Emerging Markets 350 Index', 1),
        ]
    },

]
# Run the comparison
summary = compare_portfolios(
    portfolios_to_compare,
    risk_free_rate=3.5,
    sip_amount=10000,
    show_plots=False,
    export_csv=True,
    search_path='.',          # where your CSV files are
    recursive=False,
    output_fname="example",
    # start_date=None,        # new
    # end_date=None
    # start_date='2011-01-01',
    # end_date='2010-12-31',        # new

)
# Out:
# ...
#  COMPARING 8 PORTFOLIOS
# ...
#  Unique indices needed: 8
#    - MSCI EM Quality Index
#    - RAFI Dynamic Multi-Factor Developed ex US Index
#    - RAFI Dynamic Multi-Factor Emerging Markets Index
#    - RAFI Fundamental Developed ex US Index
#    - RAFI Fundamental Emerging Markets Index
#    - RAFI Fundamental Select Developed ex US 1000 Index
#    - RAFI Fundamental Select Developed ex US 1500 Index
#    - RAFI Fundamental Select Emerging Markets 350 Index
#
# 📂 Loading index data...
#
# ✅ Global common date grid: 2007-05-03 to 2026-03-06 (4893 days)
#
# [1/8] Processing: MF Dev-ex-US
# ------------------------------------------------------------
# ❌ Error processing MF Dev-ex-US: float division by zero
#
# [2/8] Processing: MF-EM
# ------------------------------------------------------------
# ❌ Error processing MF-EM: float division by zero
#
# [3/8] Processing: Fun-Dev-ex-US
# ------------------------------------------------------------
# ...
