# %%
from US_indices.data_helpers import plot_cash_with_regimes

cash_csv = "US_indices/US 3M T-Bill Index.csv"
out_path = plot_cash_with_regimes(
    cash_index_csv=cash_csv,
    start_date="1992-01-01",
    rate_series_id="DFF",
    recession_series_id="USREC",
    sp500_series_id="SP500",
    save_path="/tmp/us_3m_tbill_regimes.png"
)
print(out_path)
# Out:
# /tmp/us_3m_tbill_regimes.png
