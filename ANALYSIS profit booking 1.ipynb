# %%
import US_indices.composite_portfolio_analysis_Buy_and_Hold as cpa
from importlib import reload
reload(cpa)

from US_indices.composite_portfolio_analysis_Buy_and_Hold import compare_portfolios

# %% [markdown]
# # EM index

# %%
# Define two portfolio options
portfolios_to_compare = [
    {
        'name': 'RAFIFunHighLiq-EM',
        'weights': [
            ('RAFI Fundamental High Liquidity Emerging Markets Large Index', 1),
        ]
    },
    # {
    #     'name': 'FunSel-EM-350',
    #     'weights': [
    #         ('RAFI Fundamental Select Emerging Markets 350 Index', 1),
    #     ]
    # },

]
# Run the comparison
summary = compare_portfolios(
    portfolios_to_compare,
    risk_free_rate=3.5,
    sip_amount=10000,
    show_plots=False,
    export_csv=False,
    search_path='.',          # where your CSV files are
    recursive=True,
    output_fname="example",
    # start_date=None,        # new
    # end_date=None
    # start_date='2011-01-01',
    # end_date='2010-12-31',        # new
    data_format='auto',
    plot_running_cagr=True,
    running_cagr_periods=[3,4,5,7,10],
    # running_cagr_periods=[2,3,4,5],
    plot_running_xirr=False,
    plot_rolling_returns_percentiles=True,
    rolling_percentiles_to_show=[0,5, 10, 25, 50, 75, 85, 90, 95,100],
    display_rolling_returns_table=False,
    interactive_cagr=True
)
# Out:
# ====================================================================================================
#  COMPARING 1 PORTFOLIOS
# ====================================================================================================
#  Unique indices needed: 1
#    - RAFI Fundamental High Liquidity Emerging Markets Large Index
#
# 📂 Loading index data...
#
# ✅ Global common date grid: 1996-04-02 to 2026-03-20 (7753 days)
#
# [1/1] Processing: RAFIFunHighLiq-EM
# ------------------------------------------------------------
# ✅ Successfully processed: RAFIFunHighLiq-EM
#
# 📊 COMBINED SUMMARY - ALL PORTFOLIOS (COMMON DATES)
# ====================================================================================================
#                                  Date Range Total Trading Days Start Value End Value Total Return % CAGR % Annualized Volatility % Sharpe Ratio Max Drawdown % Max Drawdown Date SIP XIRR % SIP Return % SIP Invested Amt SIP Final Amt Positive Days % Negative Days % Max Daily Return % Min Daily Return % 3Y Rolling Avg % 3Y Rolling Median % 3Y Rolling Min % 3Y Rolling Max % 5Y Rolling Avg % 5Y Rolling Median % 5Y Rolling Min % 5Y Rolling Max % 7Y Rolling Avg % 7Y Rolling Median % 7Y Rolling Min % 7Y Rolling Max % 10Y Rolling Avg % 10Y Rolling Median % 10Y Rolling Min % 10Y Rolling Max % 2026 Return % 2025 Return % 2024 Return % 2023 Return % 2022 Return %
# RAFIFunHighLiq-EM  1996-04-03 to 2026-03-20               7752         1.0     26.19        2529.72  11.53                   19.06        0.421         -63.27        2008-10-27     12.35%       810.41          3600000   32774641.64           54.66           44.93              13.81              -10.0            12.52                9.24           -14.02            61.62             12.1                8.99            -8.94            48.21            12.26                9.17            -1.31            34.45             12.11                10.71              0.84             31.27       3.38357     30.185547     14.701448      18.86621    -12.236271
#
# 📈 Generating comparison plots...
# 📊 Precomputing rolling returns for all periods...
#    Computing 3Y rolling returns...
#    Computing 4Y rolling returns...
#    Computing 5Y rolling returns...
#    Computing 7Y rolling returns...
#    Computing 10Y rolling returns...
# ✅ Precomputation complete!
#
# ================================================================================
#  INTERACTIVE RUNNING CAGR PLOT
# ================================================================================
# Rolling periods available: [3, 4, 5, 7, 10]
# Use the slider below to select the rolling period
# --------------------------------------------------------------------------------
# interactive(children=(SelectionSlider(description='Rolling Period (years):', layout=Layout(width='500px'), opt…

# %% [markdown]
# # Dev ex US index

# %%
# Define two portfolio options
portfolios_to_compare = [

    {
        'name': 'MultiFac Dev-ex-US',
        'weights': [
            ('RAFI Dynamic Multi-Factor Developed ex US Index', 1),
        ]
    },
    # {
    #     'name': 'FunSel-EM-350',
    #     'weights': [
    #         ('RAFI Fundamental Select Emerging Markets 350 Index', 1),
    #     ]
    # },

]
# Run the comparison
summary = compare_portfolios(
    portfolios_to_compare,
    risk_free_rate=3.5,
    sip_amount=10000,
    show_plots=False,
    export_csv=False,
    search_path='.',          # where your CSV files are
    recursive=True,
    output_fname="example",
    # start_date=None,        # new
    # end_date=None
    # start_date='2011-01-01',
    # end_date='2010-12-31',        # new
    data_format='auto',
    plot_running_cagr=True,
    running_cagr_periods=[3,4,5,7,10],
    # running_cagr_periods=[2,3,4,5],
    plot_running_xirr=False,
    plot_rolling_returns_percentiles=True,
    rolling_percentiles_to_show=[0,5, 10, 25, 50, 75, 85, 90, 95,100],
    display_rolling_returns_table=False,
    interactive_cagr=True
)
# Out:
# ====================================================================================================
#  COMPARING 1 PORTFOLIOS
# ====================================================================================================
#  Unique indices needed: 1
#    - RAFI Dynamic Multi-Factor Developed ex US Index
#
# 📂 Loading index data...
#
# ✅ Global common date grid: 1992-05-04 to 2026-03-20 (8788 days)
#
# [1/1] Processing: MultiFac Dev-ex-US
# ------------------------------------------------------------
# ✅ Successfully processed: MultiFac Dev-ex-US
#
# 📊 COMBINED SUMMARY - ALL PORTFOLIOS (COMMON DATES)
# ====================================================================================================
#                                   Date Range Total Trading Days Start Value End Value Total Return % CAGR % Annualized Volatility % Sharpe Ratio Max Drawdown % Max Drawdown Date SIP XIRR % SIP Return % SIP Invested Amt SIP Final Amt Positive Days % Negative Days % Max Daily Return % Min Daily Return % 3Y Rolling Avg % 3Y Rolling Median % 3Y Rolling Min % 3Y Rolling Max % 5Y Rolling Avg % 5Y Rolling Median % 5Y Rolling Min % 5Y Rolling Max % 7Y Rolling Avg % 7Y Rolling Median % 7Y Rolling Min % 7Y Rolling Max % 10Y Rolling Avg % 10Y Rolling Median % 10Y Rolling Min % 10Y Rolling Max % 2026 Return % 2025 Return % 2024 Return % 2023 Return % 2022 Return %
# MultiFac Dev-ex-US  1992-05-05 to 2026-03-20               8787         1.0     22.69         2171.9   9.66                   14.33         0.43         -54.93        2009-03-09      9.68%       599.36          4070000   28464026.84           53.06           44.74               7.02             -10.25             9.03                8.84            -14.3            35.17             8.75                8.15            -4.47            28.29             8.52                7.86             0.96            17.42              8.54                 8.48               3.3             14.62      1.062783      35.27588      5.266384     17.062975     -9.676542
#
# 📈 Generating comparison plots...
# 📊 Precomputing rolling returns for all periods...
#    Computing 3Y rolling returns...
#    Computing 4Y rolling returns...
#    Computing 5Y rolling returns...
#    Computing 7Y rolling returns...
#    Computing 10Y rolling returns...
# ✅ Precomputation complete!
#
# ================================================================================
#  INTERACTIVE RUNNING CAGR PLOT
# ================================================================================
# Rolling periods available: [3, 4, 5, 7, 10]
# Use the slider below to select the rolling period
# --------------------------------------------------------------------------------
# interactive(children=(SelectionSlider(description='Rolling Period (years):', layout=Layout(width='500px'), opt…

# %%
# Define two portfolio options
portfolios_to_compare = [

    {
        'name': 'FunHighLiq-Dev-ex-US-L',
        'weights': [
            ('RAFI Fundamental High Liquidity Developed ex US Large Index', 1),
        ]
    },
    # {
    #     'name': 'FunSel-EM-350',
    #     'weights': [
    #         ('RAFI Fundamental Select Emerging Markets 350 Index', 1),
    #     ]
    # },

]
# Run the comparison
summary = compare_portfolios(
    portfolios_to_compare,
    risk_free_rate=3.5,
    sip_amount=10000,
    show_plots=False,
    export_csv=False,
    search_path='.',          # where your CSV files are
    recursive=True,
    output_fname="example",
    # start_date=None,        # new
    # end_date=None
    # start_date='2011-01-01',
    # end_date='2010-12-31',        # new
    data_format='auto',
    plot_running_cagr=True,
    running_cagr_periods=[3,4,5,7,10],
    # running_cagr_periods=[2,3,4,5],
    plot_running_xirr=False,
    plot_rolling_returns_percentiles=True,
    rolling_percentiles_to_show=[0,5, 10, 25, 50, 75, 80,85, 90, 95,100],
    display_rolling_returns_table=False,
    interactive_cagr=True
)
# Out:
# ====================================================================================================
#  COMPARING 1 PORTFOLIOS
# ====================================================================================================
#  Unique indices needed: 1
#    - RAFI Fundamental High Liquidity Developed ex US Large Index
#
# 📂 Loading index data...
#
# ✅ Global common date grid: 1984-04-03 to 2026-03-20 (10853 days)
#
# [1/1] Processing: FunHighLiq-Dev-ex-US-L
# ------------------------------------------------------------
# ✅ Successfully processed: FunHighLiq-Dev-ex-US-L
#
# 📊 COMBINED SUMMARY - ALL PORTFOLIOS (COMMON DATES)
# ====================================================================================================
#                                       Date Range Total Trading Days Start Value End Value Total Return % CAGR % Annualized Volatility % Sharpe Ratio Max Drawdown % Max Drawdown Date SIP XIRR % SIP Return % SIP Invested Amt SIP Final Amt Positive Days % Negative Days % Max Daily Return % Min Daily Return % 3Y Rolling Avg % 3Y Rolling Median % 3Y Rolling Min % 3Y Rolling Max % 5Y Rolling Avg % 5Y Rolling Median % 5Y Rolling Min % 5Y Rolling Max % 7Y Rolling Avg % 7Y Rolling Median % 7Y Rolling Min % 7Y Rolling Max % 10Y Rolling Avg % 10Y Rolling Median % 10Y Rolling Min % 10Y Rolling Max % 2026 Return % 2025 Return % 2024 Return % 2023 Return % 2022 Return %
# FunHighLiq-Dev-ex-US-L  1984-04-04 to 2026-03-20              10852         1.0     85.22        8407.39  11.17                   15.17        0.506         -54.71        2009-03-09      10.1%      1279.38          5040000   69520543.47           53.57           45.72               7.95             -12.23            10.53                9.24           -15.72            55.12             9.48                8.26            -5.28            36.37             8.91                8.31            -0.81            25.38               8.8                 8.62              1.88             21.25      5.684252     41.544592      3.853112      21.21776      -7.41505
#
# 📈 Generating comparison plots...
# 📊 Precomputing rolling returns for all periods...
#    Computing 3Y rolling returns...
#    Computing 4Y rolling returns...
#    Computing 5Y rolling returns...
#    Computing 7Y rolling returns...
#    Computing 10Y rolling returns...
# ✅ Precomputation complete!
#
# ================================================================================
#  INTERACTIVE RUNNING CAGR PLOT
# ================================================================================
# Rolling periods available: [3, 4, 5, 7, 10]
# Use the slider below to select the rolling period
# --------------------------------------------------------------------------------
# interactive(children=(SelectionSlider(description='Rolling Period (years):', layout=Layout(width='500px'), opt…

# %% [markdown]
# # Composite Portfolio (EM + Dev ex US)

# %%
# Define two portfolio options
portfolios_to_compare = [
    {
        'name': 'EM_Dev-ex-US (50-50)',  
        'weights': [
            ('RAFI Fundamental High Liquidity Developed ex US Large Index', 0.25),
            ('RAFI Dynamic Multi-Factor Developed ex US Index', 0.25),
            ('RAFI Fundamental High Liquidity Emerging Markets Large Index', 0.5),
        ]
    },

    {
        'name': 'FunHighLiq-Dev-ex-US-L',
        'weights': [
            ('RAFI Fundamental High Liquidity Developed ex US Large Index', 1),
        ]
    },
    {
        'name': 'MultiFac Dev-ex-US',
        'weights': [
            ('RAFI Dynamic Multi-Factor Developed ex US Index', 1),
        ]
    },
    {
        'name': 'RAFIFunHighLiq-EM',
        'weights': [
            ('RAFI Fundamental High Liquidity Emerging Markets Large Index', 1),
        ]
    },
    # {
    #     'name': 'FunSel-EM-350',
    #     'weights': [
    #         ('RAFI Fundamental Select Emerging Markets 350 Index', 1),
    #     ]
    # },

]
# Run the comparison
summary = compare_portfolios(
    portfolios_to_compare,
    risk_free_rate=3.5,
    sip_amount=10000,
    show_plots=False,
    export_csv=False,
    search_path='.',          # where your CSV files are
    recursive=True,
    output_fname="example",
    # start_date=None,        # new
    # end_date=None
    # start_date='2011-01-01',
    # end_date='2010-12-31',        # new
    data_format='auto',
    plot_running_cagr=True,
    running_cagr_periods=[3,4,5,7,10],
    # running_cagr_periods=[2,3,4,5],
    plot_running_xirr=False,
    plot_rolling_returns_percentiles=False,
    rolling_percentiles_to_show=[0,5, 10, 25, 50, 75, 80,85, 90, 95,100],
    display_rolling_returns_table=False,
    interactive_cagr=True
)
# Out:
# ====================================================================================================
#  COMPARING 4 PORTFOLIOS
# ====================================================================================================
#  Unique indices needed: 3
#    - RAFI Dynamic Multi-Factor Developed ex US Index
#    - RAFI Fundamental High Liquidity Developed ex US Large Index
#    - RAFI Fundamental High Liquidity Emerging Markets Large Index
#
# 📂 Loading index data...
#
# ✅ Global common date grid: 1996-04-02 to 2026-03-20 (7750 days)
#
# [1/4] Processing: EM_Dev-ex-US (50-50)
# ------------------------------------------------------------
# ✅ Successfully processed: EM_Dev-ex-US (50-50)
#
# [2/4] Processing: FunHighLiq-Dev-ex-US-L
# ------------------------------------------------------------
# ✅ Successfully processed: FunHighLiq-Dev-ex-US-L
#
# [3/4] Processing: MultiFac Dev-ex-US
# ------------------------------------------------------------
# ✅ Successfully processed: MultiFac Dev-ex-US
#
# [4/4] Processing: RAFIFunHighLiq-EM
# ------------------------------------------------------------
# ✅ Successfully processed: RAFIFunHighLiq-EM
#
# 📊 COMBINED SUMMARY - ALL PORTFOLIOS (COMMON DATES)
# ====================================================================================================
#                                       Date Range Total Trading Days Start Value End Value Total Return % CAGR % Annualized Volatility % Sharpe Ratio Max Drawdown % Max Drawdown Date SIP XIRR % SIP Return % SIP Invested Amt SIP Final Amt Positive Days % Negative Days % Max Daily Return % Min Daily Return % 3Y Rolling Avg % 3Y Rolling Median % 3Y Rolling Min % 3Y Rolling Max % 5Y Rolling Avg % 5Y Rolling Median % 5Y Rolling Min % 5Y Rolling Max % 7Y Rolling Avg % 7Y Rolling Median % 7Y Rolling Min % 7Y Rolling Max % 10Y Rolling Avg % 10Y Rolling Median % 10Y Rolling Min % 10Y Rolling Max % 2026 Return % 2025 Return % 2024 Return % 2023 Return % 2022 Return %
# EM_Dev-ex-US (50-50)    1996-04-03 to 2026-03-20               7749         1.0     19.71        1875.22  10.47                    16.2         0.43         -59.71        2009-03-03     11.03%       601.11          3600000   25240089.49           55.34           44.66               9.64              -8.97            10.59                8.32           -12.42            48.76             10.2                8.09             -5.4            39.33            10.33                8.24            -0.94            26.07             10.32                 9.55              1.79             22.06       3.32369     32.746036     11.400417     18.874116    -11.053816
# FunHighLiq-Dev-ex-US-L  1996-04-03 to 2026-03-20               7749         1.0     12.57        1156.21   8.81                   15.72        0.338         -54.71        2009-03-09      9.58%        429.3          3600000   19054712.17           53.19           45.94               7.95             -10.05             8.16                8.19           -15.72            34.13             7.63                 6.9            -5.63            25.93             7.58                7.59            -0.81            15.63              7.58                 7.33              1.69             13.95      5.684252     41.544592      3.853112      21.21776      -7.41505
# MultiFac Dev-ex-US      1996-04-03 to 2026-03-20               7749         1.0      13.9        1290.65   9.18                   14.85        0.383         -54.93        2009-03-09      9.65%        436.2          3600000   19303132.23           53.21           44.75               7.02             -10.25             8.68                8.19            -14.3            34.53             8.33                7.26            -4.47            28.41             8.45                7.93             0.31            17.45              8.52                 8.32              3.26              14.7      1.062783      35.27588       6.09018     16.999216     -9.676542
# RAFIFunHighLiq-EM       1996-04-03 to 2026-03-20               7749         1.0     26.19        2529.72  11.53                   19.07        0.421         -63.27        2008-10-27     12.35%       810.41          3600000   32774725.33           54.65           44.95              13.81              -10.0            12.52                9.23           -14.02            61.62            12.11                9.03             -9.0            48.21            12.26                9.17            -1.31            34.45             12.12                10.66              1.02             31.27       3.38357     30.185547     14.701448      18.86621    -12.236271
#
# 📈 Generating comparison plots...
# 📊 Precomputing rolling returns for all periods...
#    Computing 3Y rolling returns...
#    Computing 4Y rolling returns...
#    Computing 5Y rolling returns...
#    Computing 7Y rolling returns...
#    Computing 10Y rolling returns...
# ✅ Precomputation complete!
#
# ================================================================================
#  INTERACTIVE RUNNING CAGR PLOT
# ================================================================================
# Rolling periods available: [3, 4, 5, 7, 10]
# Use the slider below to select the rolling period
# --------------------------------------------------------------------------------
# interactive(children=(SelectionSlider(description='Rolling Period (years):', layout=Layout(width='500px'), opt…

# %% [markdown]
# # 50-50 Composite Portfolio Profit Booking??

# %%
# Define two portfolio options
portfolios_to_compare = [
    {
        'name': 'EM_Dev-ex-US (50-50)',  
        'weights': [
            ('RAFI Fundamental High Liquidity Developed ex US Large Index', 0.25),
            ('RAFI Dynamic Multi-Factor Developed ex US Index', 0.25),
            ('RAFI Fundamental High Liquidity Emerging Markets Large Index', 0.5),
        ]
    },

]
# Run the comparison
summary = compare_portfolios(
    portfolios_to_compare,
    risk_free_rate=3.5,
    sip_amount=10000,
    show_plots=False,
    export_csv=False,
    search_path='.',          # where your CSV files are
    recursive=True,
    output_fname="example",
    # start_date=None,        # new
    # end_date=None
    # start_date='2011-01-01',
    # end_date='2010-12-31',        # new
    data_format='auto',
    plot_running_cagr=True,
    running_cagr_periods=[3,4,5,7,10],
    # running_cagr_periods=[2,3,4,5],
    plot_running_xirr=False,
    plot_rolling_returns_percentiles=True,
    rolling_percentiles_to_show=[0,5, 10, 25, 50, 75, 80,85, 90, 95,100],
    display_rolling_returns_table=False,
    interactive_cagr=True
)
# Out:
# ====================================================================================================
#  COMPARING 1 PORTFOLIOS
# ====================================================================================================
#  Unique indices needed: 3
#    - RAFI Dynamic Multi-Factor Developed ex US Index
#    - RAFI Fundamental High Liquidity Developed ex US Large Index
#    - RAFI Fundamental High Liquidity Emerging Markets Large Index
#
# 📂 Loading index data...
#
# ✅ Global common date grid: 1996-04-02 to 2026-03-20 (7750 days)
#
# [1/1] Processing: EM_Dev-ex-US (50-50)
# ------------------------------------------------------------
# ✅ Successfully processed: EM_Dev-ex-US (50-50)
#
# 📊 COMBINED SUMMARY - ALL PORTFOLIOS (COMMON DATES)
# ====================================================================================================
#                                     Date Range Total Trading Days Start Value End Value Total Return % CAGR % Annualized Volatility % Sharpe Ratio Max Drawdown % Max Drawdown Date SIP XIRR % SIP Return % SIP Invested Amt SIP Final Amt Positive Days % Negative Days % Max Daily Return % Min Daily Return % 3Y Rolling Avg % 3Y Rolling Median % 3Y Rolling Min % 3Y Rolling Max % 5Y Rolling Avg % 5Y Rolling Median % 5Y Rolling Min % 5Y Rolling Max % 7Y Rolling Avg % 7Y Rolling Median % 7Y Rolling Min % 7Y Rolling Max % 10Y Rolling Avg % 10Y Rolling Median % 10Y Rolling Min % 10Y Rolling Max % 2026 Return % 2025 Return % 2024 Return % 2023 Return % 2022 Return %
# EM_Dev-ex-US (50-50)  1996-04-03 to 2026-03-20               7749         1.0     19.71        1875.22  10.47                    16.2         0.43         -59.71        2009-03-03     11.03%       601.11          3600000   25240089.49           55.34           44.66               9.64              -8.97            10.59                8.32           -12.42            48.76             10.2                8.09             -5.4            39.33            10.33                8.24            -0.94            26.07             10.32                 9.55              1.79             22.06       3.32369     32.746036     11.400417     18.874116    -11.053816
#
# 📈 Generating comparison plots...
# 📊 Precomputing rolling returns for all periods...
#    Computing 3Y rolling returns...
#    Computing 4Y rolling returns...
#    Computing 5Y rolling returns...
#    Computing 7Y rolling returns...
#    Computing 10Y rolling returns...
# ✅ Precomputation complete!
#
# ================================================================================
#  INTERACTIVE RUNNING CAGR PLOT
# ================================================================================
# Rolling periods available: [3, 4, 5, 7, 10]
# Use the slider below to select the rolling period
# --------------------------------------------------------------------------------
# interactive(children=(SelectionSlider(description='Rolling Period (years):', layout=Layout(width='500px'), opt…
