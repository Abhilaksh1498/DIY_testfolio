# %%
import US_indices.composite_portfolio_analysis_Buy_and_Hold as cpa
from importlib import reload
reload(cpa)

from US_indices.composite_portfolio_analysis_Buy_and_Hold import compare_portfolios


# Define two portfolio options
portfolios_to_compare = [
    {
        'name': 'Dyn-MultiFac',
        'weights': [
            ('RAFI Dynamic Multi-Factor US Index', 1),
        ]
    },
    {
        'name': 'FunHighLiq-All',
        'weights': [
            ('RAFI Fundamental High Liquidity US All Index', 1),
        ]
    },
    {
        'name': 'FunHighLiq-Large',
        'weights': [
            ('RAFI Fundamental High Liquidity US Large Index', 1),
        ]
    },
    # {
    #     'name': 'MSCI GARP',
    #     'weights': [
    #         ('MSCI USA Quality GARP Select Index', 1),
    #     ]
    # },
    
        {
        'name': 'Fun',
        'weights': [
            ('RAFI Fundamental US Index', 1),
        ]
    },
    {
        'name': 'FunSel-1000',
        'weights': [
            ('RAFI Fundamental Select US 1000 Index', 1),
        ]
    },

]
# Run the comparison
summary = compare_portfolios(
    portfolios_to_compare,
    risk_free_rate=3.5,
    sip_amount=10000,
    show_plots=False,
    export_csv=False,
    search_path='.',          # where your CSV files are
    recursive=True,
    output_fname="example",
    # start_date=None,        # new
    # end_date=None
    # start_date='2000-01-01',
    # end_date='2010-01-01',        # new
    data_format='auto',
    plot_running_cagr=True,
    running_cagr_periods=[2,3,4,5],
    plot_running_xirr=False,
    interactive_cagr=True

)
# Out:
# ====================================================================================================
#  COMPARING 5 PORTFOLIOS
# ====================================================================================================
#  Unique indices needed: 5
#    - RAFI Dynamic Multi-Factor US Index
#    - RAFI Fundamental High Liquidity US All Index
#    - RAFI Fundamental High Liquidity US Large Index
#    - RAFI Fundamental Select US 1000 Index
#    - RAFI Fundamental US Index
#
# 📂 Loading index data...
#
# ✅ Global common date grid: 1992-05-04 to 2026-03-30 (8640 days)
#
# [1/5] Processing: Dyn-MultiFac
# ------------------------------------------------------------
#    📁 Exported: Dyn-MultiFac_data.csv
# ✅ Successfully processed: Dyn-MultiFac
#
# [2/5] Processing: FunHighLiq-All
# ------------------------------------------------------------
#    📁 Exported: FunHighLiq-All_data.csv
# ✅ Successfully processed: FunHighLiq-All
#
# [3/5] Processing: FunHighLiq-Large
# ------------------------------------------------------------
#    📁 Exported: FunHighLiq-Large_data.csv
# ✅ Successfully processed: FunHighLiq-Large
#
# [4/5] Processing: Fun
# ------------------------------------------------------------
#    📁 Exported: Fun_data.csv
# ✅ Successfully processed: Fun
#
# [5/5] Processing: FunSel-1000
# ------------------------------------------------------------
#    📁 Exported: FunSel-1000_data.csv
# ✅ Successfully processed: FunSel-1000
#
# 📊 COMBINED SUMMARY - ALL PORTFOLIOS (COMMON DATES)
# ====================================================================================================
#                                 Date Range Total Trading Days Start Value End Value Total Return % CAGR % Annualized Volatility % Sharpe Ratio Max Drawdown % Max Drawdown Date SIP XIRR % SIP Return % SIP Invested Amt SIP Final Amt Positive Days % Negative Days % Max Daily Return % Min Daily Return % 3Y Rolling Avg % 3Y Rolling Median % 3Y Rolling Min % 3Y Rolling Max % 5Y Rolling Avg % 5Y Rolling Median % 5Y Rolling Min % 5Y Rolling Max % 7Y Rolling Avg % 7Y Rolling Median % 7Y Rolling Min % 7Y Rolling Max % 10Y Rolling Avg % 10Y Rolling Median % 10Y Rolling Min % 10Y Rolling Max % 2026 Return % 2025 Return % 2024 Return % 2023 Return % 2022 Return %
# Dyn-MultiFac      1992-05-05 to 2026-03-30               8639         1.0     51.19        5008.17   12.3                   16.33        0.539         -49.26        2009-03-09     12.12%      1118.75          4070000   49602957.73           54.22           44.39              11.18             -11.95            12.28               12.28           -13.93            30.73            12.01               12.38            -3.04            26.11             11.5               10.95            -0.69            20.13             11.16                11.38              1.87             17.79       0.31433     16.203691     20.661007     13.012994     -6.090882
# FunHighLiq-All    1992-05-05 to 2026-03-30               8639         1.0     57.23        5621.57  12.68                   17.48        0.525         -53.62        2009-03-09     12.51%      1232.34          4070000   54226061.24           53.94           44.88              11.02             -11.89            12.75               13.33           -16.43            34.61            12.46               12.47            -5.11            27.85            11.86               11.88            -1.87            21.02             11.43                11.64              1.21             18.52     -0.090874     16.884834     15.999523     18.904789     -5.248774
# FunHighLiq-Large  1992-05-05 to 2026-03-30               8639         1.0     55.71        5471.69  12.59                   17.36        0.524         -53.06        2009-03-09     12.43%      1208.04          4070000   53237233.03            53.9           44.91              11.15             -11.75            12.66               13.34           -16.06            33.56            12.33               12.36            -5.02            27.27             11.7               11.79             -2.0            21.29             11.24                11.63              0.77             18.24     -0.060368     17.568523     16.512375     18.775897     -4.204365
# Fun               1992-05-05 to 2026-03-30               8639         1.0     43.76        4275.28  11.79                   17.45        0.475         -57.14        2009-03-09     11.65%        993.5          4070000   44505291.48            53.4           44.99              11.47             -12.12            11.84               12.54           -18.54            32.66            11.47               11.95            -7.28            26.45             10.8               11.16            -3.92            20.96             10.28                11.19             -1.24             17.67     -0.969054     19.420034     17.437679     19.289095     -7.884836
# FunSel-1000       1992-05-05 to 2026-03-30               8639         1.0     42.76         4173.4  11.71                   17.73        0.463         -57.83        2009-03-09     11.55%       968.23          4070000   43477131.41           53.84           44.96              11.22             -12.07            11.77               12.58           -19.27            32.53            11.39               11.89            -8.06            26.47            10.68               11.13            -4.49            21.46              10.1                11.19              -1.7             17.74     -1.180744     19.015242     16.518673     19.535581     -7.951153
#
# ====================================================================================================
#  ROLLING X-YEAR RETURNS PERCENTILE SUMMARY
# ====================================================================================================
#
# 📊 CONSOLIDATED ROLLING RETURNS SUMMARY
#        Portfolio  Period (Yrs)  Count  Mean %  Median %  Std %  5th %  10th %  50th %  90th %  95th %
#     Dyn-MultiFac             3   7883   12.28     12.28   7.51  -2.45    1.20   12.28   21.31   23.76
#   FunHighLiq-All             3   7883   12.75     13.33   7.74  -2.19    1.68   13.33   21.96   25.04
# FunHighLiq-Large             3   7883   12.66     13.34   7.87  -2.32    1.04   13.34   22.16   25.12
#              Fun             3   7883   11.84     12.54   8.28  -5.00    0.38   12.54   21.39   25.01
#      FunSel-1000             3   7883   11.77     12.58   8.51  -5.37   -0.52   12.58   21.37   25.10
#     Dyn-MultiFac             5   7379   12.01     12.38   5.50   3.36    4.51   12.38   20.06   21.21
#   FunHighLiq-All             5   7379   12.46     12.47   5.78   2.95    4.34   12.47   20.29   21.77
# FunHighLiq-Large             5   7379   12.33     12.36   5.93   2.75    4.16   12.36   20.48   21.91
#              Fun             5   7379   11.47     11.95   6.36   0.70    2.19   11.95   19.93   21.65
#      FunSel-1000             5   7379   11.39     11.89   6.63   0.24    1.76   11.89   20.25   21.88
#     Dyn-MultiFac             7   6875   11.50     10.95   3.42   6.94    7.90   10.95   17.13   17.79
#   FunHighLiq-All             7   6875   11.86     11.88   3.67   6.52    7.58   11.88   17.80   18.65
# FunHighLiq-Large             7   6875   11.70     11.79   3.80   6.30    7.33   11.79   17.83   18.80
#              Fun             7   6875   10.80     11.16   4.28   4.41    5.52   11.16   17.21   18.22
#      FunSel-1000             7   6875   10.68     11.13   4.54   3.91    5.00   11.13   17.33   18.45
#     Dyn-MultiFac            10   6119   11.16     11.38   2.60   5.97    7.60   11.38   14.29   14.93
#   FunHighLiq-All            10   6119   11.43     11.64   2.80   6.60    7.55   11.64   14.95   15.47
# FunHighLiq-Large            10   6119   11.24     11.63   2.88   6.09    7.10   11.63   14.78   15.27
#              Fun            10   6119   10.28     11.19   3.35   4.48    5.38   11.19   14.28   14.84
#      FunSel-1000            10   6119   10.10     11.19   3.56   3.87    4.81   11.19   14.27   14.90
#
# ====================================================================================================
# ====================================================================================================
#
# 📈 Generating comparison plots...
# 📊 Precomputing rolling returns for all periods...
#    Computing 2Y rolling returns...
#    Computing 3Y rolling returns...
#    Computing 4Y rolling returns...
#    Computing 5Y rolling returns...
# ✅ Precomputation complete!
#
# ================================================================================
#  INTERACTIVE RUNNING CAGR PLOT
# ================================================================================
# Rolling periods available: [2, 3, 4, 5]
# Use the slider below to select the rolling period
# --------------------------------------------------------------------------------
# interactive(children=(SelectionSlider(description='Rolling Period (years):', layout=Layout(width='500px'), opt…
# 📁 Exported: portfolios_comparison_summary_example.csv

# %%
import US_indices.composite_portfolio_analysis_Buy_and_Hold as cpa
from importlib import reload
reload(cpa)

from US_indices.composite_portfolio_analysis_Buy_and_Hold import compare_portfolios


# Define two portfolio options
portfolios_to_compare = [
    {
        'name': 'GARP-RAFI : 50-50',
        'weights': [
            ('RAFI Dynamic Multi-Factor US Index', 0.3),
            ('MSCI USA Quality GARP Select Index', 0.6),
            ('RAFI Fundamental High Liquidity US Large Index', 0.3),
        ]
    },
    {
        'name': 'FunHighLiq-Large',
        'weights': [
            ('RAFI Fundamental High Liquidity US Large Index', 1),
        ]
    },

    {
        'name': 'MSCI GARP',
        'weights': [
            ('MSCI USA Quality GARP Select Index', 1),
        ]
    },
        {
        'name': 'Dyn-MultiFac',
        'weights': [
            ('RAFI Dynamic Multi-Factor US Index', 1),
        ]
    },
    {
        'name': 'FunHighLiq-Large',
        'weights': [
            ('RAFI Fundamental High Liquidity US Large Index', 1),
        ]
    },

]
# Run the comparison
summary = compare_portfolios(
    portfolios_to_compare,
    risk_free_rate=3.5,
    sip_amount=10000,
    show_plots=False,
    export_csv=False,
    search_path='.',          # where your CSV files are
    recursive=True,
    output_fname="example",
    # start_date=None,        # new
    # end_date=None
    start_date='2004-01-30',
    end_date='2010-01-01',        # new
    data_format='auto',
    plot_running_cagr=True,
    running_cagr_periods=[2,3,4,5],
    plot_running_xirr=False,
    interactive_cagr=True

)
# Out:
# ====================================================================================================
#  COMPARING 5 PORTFOLIOS
# ====================================================================================================
#  Unique indices needed: 3
#    - MSCI USA Quality GARP Select Index
#    - RAFI Dynamic Multi-Factor US Index
#    - RAFI Fundamental High Liquidity US Large Index
#
# 📂 Loading index data...
#
# ✅ Global common date grid: 2004-01-30 to 2009-12-31 (1514 days)
#
# [1/5] Processing: GARP-RAFI : 50-50
# ------------------------------------------------------------
#    📁 Exported: GARP-RAFI_:_50-50_data.csv
# ✅ Successfully processed: GARP-RAFI : 50-50
#
# [2/5] Processing: FunHighLiq-Large
# ------------------------------------------------------------
#    📁 Exported: FunHighLiq-Large_data.csv
# ✅ Successfully processed: FunHighLiq-Large
#
# [3/5] Processing: MSCI GARP
# ------------------------------------------------------------
#    📁 Exported: MSCI_GARP_data.csv
# ✅ Successfully processed: MSCI GARP
#
# [4/5] Processing: Dyn-MultiFac
# ------------------------------------------------------------
#    📁 Exported: Dyn-MultiFac_data.csv
# ✅ Successfully processed: Dyn-MultiFac
#
# [5/5] Processing: FunHighLiq-Large
# ------------------------------------------------------------
#    📁 Exported: FunHighLiq-Large_data.csv
# ✅ Successfully processed: FunHighLiq-Large
#
# 📊 COMBINED SUMMARY - ALL PORTFOLIOS (COMMON DATES)
# ====================================================================================================
#                                  Date Range Total Trading Days Start Value End Value Total Return % CAGR % Annualized Volatility % Sharpe Ratio Max Drawdown % Max Drawdown Date SIP XIRR % SIP Return % SIP Invested Amt SIP Final Amt Positive Days % Negative Days % Max Daily Return % Min Daily Return % 3Y Rolling Avg % 3Y Rolling Median % 3Y Rolling Min % 3Y Rolling Max % 5Y Rolling Avg % 5Y Rolling Median % 5Y Rolling Min % 5Y Rolling Max %
# GARP-RAFI : 50-50  2004-02-02 to 2009-12-31               1513         1.2      1.55          28.47   4.33                   22.09        0.038          -52.6        2009-03-09      1.97%         5.92           710000     752017.28           55.06           43.49              12.42               -9.5             3.28                5.31           -16.41            17.33             0.66                0.82             -5.7             4.01
# FunHighLiq-Large   2004-02-02 to 2009-12-31               1513         1.0      1.39          38.53   5.67                   22.13        0.098         -53.06        2009-03-09       3.6%        11.07           710000     788601.79           55.12           43.42              11.15              -9.08             4.45                5.91           -16.06            19.21              2.0                2.17            -5.02             5.79
# MSCI GARP          2004-02-02 to 2009-12-31               1513         1.0      1.17          16.17   2.57                   23.34        -0.04         -54.72        2009-03-09      0.51%         1.51           710000     720749.17           54.33           44.22              13.99             -10.21             1.43                3.77           -18.06            14.97            -1.23               -0.88            -7.55             2.05
# Dyn-MultiFac       2004-02-02 to 2009-12-31               1513         1.0      1.43          43.09   6.25                   20.48        0.134         -49.26        2009-03-09      3.02%         9.21           710000     775396.28           54.92           43.42              11.18               -8.8             5.49                7.56           -13.93            20.03             2.79                 2.7            -3.04             5.78
#
# ====================================================================================================
#  ROLLING X-YEAR RETURNS PERCENTILE SUMMARY
# ====================================================================================================
#    ⚠️  GARP-RAFI : 50-50: insufficient data for 7‑year rolling returns
#    ⚠️  FunHighLiq-Large: insufficient data for 7‑year rolling returns
#    ⚠️  MSCI GARP: insufficient data for 7‑year rolling returns
#    ⚠️  Dyn-MultiFac: insufficient data for 7‑year rolling returns
#    ⚠️  GARP-RAFI : 50-50: insufficient data for 10‑year rolling returns
#    ⚠️  FunHighLiq-Large: insufficient data for 10‑year rolling returns
#    ⚠️  MSCI GARP: insufficient data for 10‑year rolling returns
#    ⚠️  Dyn-MultiFac: insufficient data for 10‑year rolling returns
#
# 📊 CONSOLIDATED ROLLING RETURNS SUMMARY
#         Portfolio  Period (Yrs)  Count  Mean %  Median %  Std %  5th %  10th %  50th %  90th %  95th %
# GARP-RAFI : 50-50             3    757    3.28      5.31   9.33 -10.84   -9.73    5.31   14.57   15.45
#  FunHighLiq-Large             3    757    4.45      5.91   9.42  -9.74   -8.23    5.91   16.45   17.26
#         MSCI GARP             3    757    1.43      3.77   9.22 -13.18  -11.93    3.77   12.01   12.90
#      Dyn-MultiFac             3    757    5.49      7.56   9.68  -8.52   -6.80    7.56   17.54   18.39
# GARP-RAFI : 50-50             5    253    0.66      0.82   2.32  -3.47   -2.54    0.82    3.14    3.46
#  FunHighLiq-Large             5    253    2.00      2.17   2.57  -2.62   -1.59    2.17    4.75    5.01
#         MSCI GARP             5    253   -1.23     -0.88   2.40  -5.41   -4.52   -0.88    1.30    1.59
#      Dyn-MultiFac             5    253    2.79      2.70   1.94  -0.78    0.17    2.70    4.91    5.22
#
# ====================================================================================================
# ====================================================================================================
#
# 📈 Generating comparison plots...
# 📊 Precomputing rolling returns for all periods...
#    Computing 2Y rolling returns...
#    Computing 3Y rolling returns...
#    Computing 4Y rolling returns...
#    Computing 5Y rolling returns...
# ✅ Precomputation complete!
#
# ================================================================================
#  INTERACTIVE RUNNING CAGR PLOT
# ================================================================================
# Rolling periods available: [2, 3, 4, 5]
# Use the slider below to select the rolling period
# --------------------------------------------------------------------------------
# interactive(children=(SelectionSlider(description='Rolling Period (years):', layout=Layout(width='500px'), opt…
# 📁 Exported: portfolios_comparison_summary_example.csv

# %%
# Define two portfolio options
portfolios_to_compare = [
    {
        'name': 'US Small cap',  
        'weights': [
            ('RAFI Fundamental High Liquidity US Small Index', 1),
        ]
    },
        {
        'name': 'Dyn-MultiFac',
        'weights': [
            ('RAFI Dynamic Multi-Factor US Index', 1),
        ]
    },
    {
        'name': 'FunHighLiq-Large',
        'weights': [
            ('RAFI Fundamental High Liquidity US Large Index', 1),
        ]
    },

]
# Run the comparison
summary = compare_portfolios(
    portfolios_to_compare,
    risk_free_rate=3.5,
    sip_amount=10000,
    show_plots=False,
    export_csv=False,
    search_path='.',          # where your CSV files are
    recursive=True,
    output_fname="example",
    # start_date=None,        # new
    # end_date=None
    # start_date='1995-06-30',
    # end_date='2024-03-31',        # new
    data_format='auto',
    plot_running_cagr=True,
    running_cagr_periods=[3,4,5,7,10],
    # running_cagr_periods=[2,3,4,5],
    plot_running_xirr=False,
    plot_rolling_returns_percentiles=True,
    rolling_percentiles_to_show=[0,5, 10, 25, 50, 75, 80,85, 90, 95,100],
    display_rolling_returns_table=False,
    interactive_cagr=True
)
# Out:
# ====================================================================================================
#  COMPARING 3 PORTFOLIOS
# ====================================================================================================
#  Unique indices needed: 3
#    - RAFI Dynamic Multi-Factor US Index
#    - RAFI Fundamental High Liquidity US Large Index
#    - RAFI Fundamental High Liquidity US Small Index
#
# 📂 Loading index data...
#
# ✅ Global common date grid: 1992-05-04 to 2026-03-30 (8538 days)
#
# [1/3] Processing: US Small cap
# ------------------------------------------------------------
# ✅ Successfully processed: US Small cap
#
# [2/3] Processing: Dyn-MultiFac
# ------------------------------------------------------------
# ✅ Successfully processed: Dyn-MultiFac
#
# [3/3] Processing: FunHighLiq-Large
# ------------------------------------------------------------
# ✅ Successfully processed: FunHighLiq-Large
#
# 📊 COMBINED SUMMARY - ALL PORTFOLIOS (COMMON DATES)
# ====================================================================================================
#                                 Date Range Total Trading Days Start Value End Value Total Return % CAGR % Annualized Volatility % Sharpe Ratio Max Drawdown % Max Drawdown Date SIP XIRR % SIP Return % SIP Invested Amt SIP Final Amt Positive Days % Negative Days % Max Daily Return % Min Daily Return % 3Y Rolling Avg % 3Y Rolling Median % 3Y Rolling Min % 3Y Rolling Max % 5Y Rolling Avg % 5Y Rolling Median % 5Y Rolling Min % 5Y Rolling Max % 7Y Rolling Avg % 7Y Rolling Median % 7Y Rolling Min % 7Y Rolling Max % 10Y Rolling Avg % 10Y Rolling Median % 10Y Rolling Min % 10Y Rolling Max % 2026 Return % 2025 Return % 2024 Return % 2023 Return % 2022 Return %
# US Small cap      1992-05-05 to 2026-03-30               8537         1.0     67.48        6622.45  13.22                   20.27        0.479         -59.13        2009-03-09     12.97%      1382.66          4070000   60344203.79           55.08           44.91              10.08             -13.49            13.59               14.07           -19.28            43.39            13.62               14.54            -6.36             35.6            13.32               13.29            -0.27             24.7              13.3                13.01              6.28             21.71     -0.385966      8.156758     10.084049     20.363595    -17.211184
# Dyn-MultiFac      1992-05-05 to 2026-03-30               8537         1.0     51.19        5008.17   12.3                   16.43        0.536         -49.26        2009-03-09     12.12%      1118.75          4070000   49602993.83           54.87           44.92              11.18             -11.95            12.43               12.35           -13.26            30.65            12.16               12.53            -3.36            27.69            11.63               11.09            -0.35            20.95             11.31                11.52              2.76             18.08       0.31433     16.203691     20.661007     13.012994     -6.090882
# FunHighLiq-Large  1992-05-05 to 2026-03-30               8537         1.0     55.71        5471.69  12.59                   17.47         0.52         -53.06        2009-03-09     12.43%      1208.04          4070000   53237280.75           54.54           45.45              11.15             -11.75            12.81               13.44           -15.38            33.16            12.48               12.52            -5.43            28.74            11.84               11.83            -1.98            21.19             11.38                11.76              1.92             18.62     -0.060368     17.568523     16.512375     18.775897     -4.204365
#
# 📈 Generating comparison plots...
# 📊 Precomputing rolling returns for all periods...
#    Computing 3Y rolling returns...
#    Computing 4Y rolling returns...
#    Computing 5Y rolling returns...
#    Computing 7Y rolling returns...
#    Computing 10Y rolling returns...
# ✅ Precomputation complete!
#
# ================================================================================
#  INTERACTIVE RUNNING CAGR PLOT
# ================================================================================
# Rolling periods available: [3, 4, 5, 7, 10]
# Use the slider below to select the rolling period
# --------------------------------------------------------------------------------
# interactive(children=(SelectionSlider(description='Rolling Period (years):', layout=Layout(width='500px'), opt…
